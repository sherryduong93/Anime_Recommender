# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
anime_df = pd.read_csv('data/anime.csv')
rating_df = pd.read_csv('data/rating.csv')
anime_meta = pd.read_csv('data/AnimeList_meta.csv')
users_meta = pd.read_csv('data/UserList_Meta.csv')

# %%
anime_df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
anime_df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
users_meta
# Out:
#                 username  user_id  user_watching  user_completed  user_onhold  \
# 0               karthiga  2255153              3              49            1
# 1       RedvelvetDaisuki  1897606             61             396           39
# 2              Damonashu    37326             45             195           27
# 3                  bskai   228342             25             414            2
# 4              shuzzable  2347781             36              72           16
# ...                  ...      ...            ...             ...          ...
# 302670      ScruffyPuffy  3119025              0              27            0
# 302671          Torasori  3975907             22             239            0
# 302672              onpc  1268417              5             169            2
# 302673            HMicca  1289601             11              73            2
# 302674        mini_kaila   236339              2              10            5
#
#         user_dropped  user_plantowatch  user_days_spent_watching  gender  \
# 0                  0                 0                     55.31  Female
# 1                  0               206                    118.07  Female
# 2                 25                59                     83.70    Male
# 3                  5                11                    167.16    Male
# 4                  2                25                     35.48     NaN
# ...              ...               ...                       ...     ...
# 302670             0                 0                      7.92     NaN
# 302671             4               176                     86.88    Male
# 302672             5                24                     38.36    Male
# 302673             2                16                    119.97  Female
# 302674             3                 5                      4.17  Female
#
#                    location  birth_date  access_rank   join_date  \
# 0           Chennai, India   1990-04-29          NaN  2013-03-03
# 1                    Manila  1995-01-01          NaN  2012-12-13
# 2          Detroit,Michigan  1991-08-01          NaN  2008-02-13
# 3           Nayarit, Mexico  1990-12-14          NaN  2009-08-31
# 4                       NaN         NaN          NaN  2013-03-25
# ...                     ...         ...          ...         ...
# 302670                  NaN         NaN          NaN  2013-09-06
# 302671         Latvia, Riga  1998-11-18          NaN  2014-07-30
# 302672                  NaN         NaN          NaN  2012-04-23
# 302673  Birmingham, England  1995-08-12          NaN  2012-05-05
# 302674                  NaN         NaN          NaN  2009-09-19
#
#                 last_online  stats_mean_score  stats_rewatched  stats_episodes
# 0       2014-02-04 01:32:00              7.43              0.0          3391.0
# 1       1900-05-13 02:47:00              6.78             80.0          7094.0
# 2       1900-03-24 12:48:00              6.15              6.0          4936.0
# 3       2014-05-12 16:35:00              8.27              1.0         10081.0
# 4       2015-09-09 21:54:00              9.06              7.0          2154.0
# ...                     ...               ...              ...             ...
# 302670  2014-10-10 09:04:00              0.00              0.0           477.0
# 302671  2018-05-24 21:34:46              8.98             47.0          5313.0
# 302672  2016-12-28 14:35:00              7.72              0.0          2280.0
# 302673  2012-11-15 08:10:00              8.89             11.0          7049.0
# 302674  2011-08-19 01:15:00              7.82              0.0           245.0
#
# [302675 rows x 17 columns]

# %%
anime_meta['anime_id'].nunique()
# Out:
# 14478

# %%
anime_meta.isnull().sum()
# Out:
# anime_id              0
# title                 0
# title_english      8754
# title_japanese       35
# title_synonyms     5541
# image_url            96
# type                  0
# source                0
# episodes              0
# status                0
# airing                0
# aired_string          0
# aired                 0
# duration              0
# rating                0
# score                 0
# scored_by             0
# rank               1574
# popularity            0
# members               0
# favorites             0
# background        13421
# premiered         10382
# broadcast         10207
# related               0
# producer           6190
# licensor          11105
# studio             5934
# genre                64
# opening_theme         0
# ending_theme          0
# dtype: int64

# %%
anime_meta[anime_meta['type']=='Movie']['duration']
# Out:
# 55              Unknown
# 77        1 hr. 36 min.
# 78              25 min.
# 81              49 min.
# 86               8 min.
#               ...
# 14440      1 hr. 5 min.
# 14443    4 min. per ep.
# 14446           19 min.
# 14465           20 min.
# 14475           Unknown
# Name: duration, Length: 2624, dtype: object

# %%
rating_df['user_id'].nunique()
# Out:
# 73515

# %%
rating_df
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
users_meta['user_id'].nunique()
# Out:
# 302673

# %%
rating_df['anime_id'].nunique()
# Out:
# 11200

# %%
rating_df.isnull().sum()
# Out:
# user_id     0
# anime_id    0
# rating      0
# dtype: int64

# %%
users_meta.isnull().sum()
# Out:
# username                         1
# user_id                          0
# user_watching                    0
# user_completed                   0
# user_onhold                      0
# user_dropped                     0
# user_plantowatch                 0
# user_days_spent_watching         0
# gender                       84875
# location                    145901
# birth_date                  133926
# access_rank                 302675
# join_date                      129
# last_online                    129
# stats_mean_score               129
# stats_rewatched                129
# stats_episodes                 129
# dtype: int64

# %% [markdown]
# ## Merge the dataframes into one dataframe

# %%
rating_df = rating_df[rating_df['rating']!=-1]
#remove the -1's, which are no values for the ratings

count_ratings = rating_df.groupby('anime_id').count().rename(columns={'rating': 'num_ratings'})['num_ratings']
count_ratings
# Out:
# anime_id
# 1        13449
# 5         5790
# 6         9385
# 7         2169
# 8          308
#          ...
# 34324       11
# 34325       15
# 34349        3
# 34367        4
# 34475        3
# Name: num_ratings, Length: 9927, dtype: int64

# %%
anime_full = anime_df.merge(right=anime_meta, how='left', on='anime_id')
anime_full = anime_full.merge(right=count_ratings, how='left', on='anime_id')
anime_full
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                  genre_x type_x episodes_x  \
# 0                   Drama, Romance, School, Supernatural  Movie          1
# 1      Action, Adventure, Drama, Fantasy, Magic, Mili...     TV         64
# 2      Action, Comedy, Historical, Parody, Samurai, S...     TV         51
# 3                                       Sci-Fi, Thriller     TV         24
# 4      Action, Comedy, Historical, Parody, Samurai, S...     TV         51
# ...                                                  ...    ...        ...
# 12289                                             Hentai    OVA          1
# 12290                                             Hentai    OVA          1
# 12291                                             Hentai    OVA          4
# 12292                                             Hentai    OVA          1
# 12293                                             Hentai  Movie          1
#
#        rating_x  members_x                                              title  \
# 0          9.37     200630                                     Kimi no Na wa.
# 1          9.26     793665                   Fullmetal Alchemist: Brotherhood
# 2          9.25     114262                                           Gintama°
# 3          9.17     673572                                        Steins;Gate
# 4          9.16     151266                                      Gintama&#039;
# ...         ...        ...                                                ...
# 12289      4.15        211       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      4.28        183                                        Under World
# 12291      4.88        219                     Violence Gekiga David no Hoshi
# 12292      4.98        175  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293      5.46        142                   Yasuji no Pornorama: Yacchimae!!
#
#                           title_english              title_japanese  \
# 0                            Your Name.                       君の名は。
# 1      Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 2                      Gintama Season 4                         銀魂°
# 3                           Steins;Gate                 STEINS;GATE
# 4                      Gintama Season 2                    銀魂&#039;
# ...                                 ...                         ...
# 12289                               NaN         等身大マイラバー～ミナミ対メカミナミ～
# 12290                               NaN                閻魔國 アンダーワールド
# 12291             Beautiful Girl Hunter              バイオレンス劇画 堕靡泥の星
# 12292                               NaN       バイオレンス劇画 新・堕靡泥の星 淫魔伝説
# 12293                               NaN           ヤスジのポルノラマ やっちまえ!!
#
#                                           title_synonyms  \
# 0                                                    NaN
# 1      Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 2                                   Gintama&#039; (2015)
# 3                                                    NaN
# 4                                         Gintama (2011)
# ...                                                  ...
# 12289  Be Lifesized My Lover - Mechanic Minami vs. Hu...
# 12290                                                NaN
# 12291                      Star of David: Beauty Hunting
# 12292                                                NaN
# 12293  Do It! Yasuji&#039;s Pornorama, Yasuji&#039;&#...
#
#                                                image_url type_y        source  \
# 0      https://myanimelist.cdn-dena.com/images/anime/...  Movie      Original
# 1      https://myanimelist.cdn-dena.com/images/anime/...     TV         Manga
# 2      https://myanimelist.cdn-dena.com/images/anime/...     TV         Manga
# 3      https://myanimelist.cdn-dena.com/images/anime/...     TV  Visual novel
# 4      https://myanimelist.cdn-dena.com/images/anime/...     TV         Manga
# ...                                                  ...    ...           ...
# 12289  https://myanimelist.cdn-dena.com/images/anime/...    OVA       Unknown
# 12290  https://myanimelist.cdn-dena.com/images/anime/...    OVA       Unknown
# 12291  https://myanimelist.cdn-dena.com/images/anime/...    OVA       Unknown
# 12292  https://myanimelist.cdn-dena.com/images/anime/...    OVA       Unknown
# 12293  https://myanimelist.cdn-dena.com/images/anime/...  Movie       Unknown
#
#        episodes_y           status airing                 aired_string  \
# 0             1.0  Finished Airing  False                 Aug 26, 2016
# 1            64.0  Finished Airing  False   Apr 5, 2009 to Jul 4, 2010
# 2            51.0  Finished Airing  False  Apr 8, 2015 to Mar 30, 2016
# 3            24.0  Finished Airing  False  Apr 6, 2011 to Sep 14, 2011
# 4            51.0  Finished Airing  False  Apr 4, 2011 to Mar 26, 2012
# ...           ...              ...    ...                          ...
# 12289         1.0  Finished Airing  False                 Oct 26, 2001
# 12290         1.0  Finished Airing  False                 Nov 18, 2000
# 12291         4.0  Finished Airing  False   Dec 5, 1989 to Jun 5, 1990
# 12292         1.0  Finished Airing  False                  Mar 8, 1991
# 12293         1.0  Finished Airing  False                 Sep 24, 1971
#
#                                             aired         duration  \
# 0      {'from': '2016-08-26', 'to': '2016-08-26'}    1 hr. 46 min.
# 1      {'from': '2009-04-05', 'to': '2010-07-04'}  24 min. per ep.
# 2      {'from': '2015-04-08', 'to': '2016-03-30'}  24 min. per ep.
# 3      {'from': '2011-04-06', 'to': '2011-09-14'}  24 min. per ep.
# 4      {'from': '2011-04-04', 'to': '2012-03-26'}  24 min. per ep.
# ...                                           ...              ...
# 12289  {'from': '2001-10-26', 'to': '2001-10-26'}          30 min.
# 12290  {'from': '2000-11-18', 'to': '2000-11-18'}     1 hr. 4 min.
# 12291  {'from': '1989-12-05', 'to': '1990-06-05'}  45 min. per ep.
# 12292  {'from': '1991-03-08', 'to': '1991-03-08'}          45 min.
# 12293  {'from': '1971-09-24', 'to': '1971-09-24'}    1 hr. 41 min.
#
#                              rating_y  score  scored_by  rank  popularity  \
# 0           PG-13 - Teens 13 or older   9.19   471398.0   2.0        33.0
# 1      R - 17+ (violence & profanity)   9.25   733592.0   1.0         4.0
# 2      R - 17+ (violence & profanity)   9.15    71751.0   3.0       383.0
# 3           PG-13 - Teens 13 or older   9.14   563857.0   5.0         8.0
# 4           PG-13 - Teens 13 or older   9.11    92025.0   7.0       342.0
# ...                               ...    ...        ...   ...         ...
# 12289                     Rx - Hentai   4.94       68.0   NaN     10297.0
# 12290                     Rx - Hentai   5.10       62.0   NaN     10456.0
# 12291                     Rx - Hentai   5.18       79.0   NaN     10164.0
# 12292                     Rx - Hentai   5.31       67.0   NaN     10510.0
# 12293                     Rx - Hentai   4.46       35.0   NaN     10534.0
#
#        members_y  favorites  \
# 0       730076.0    34912.0
# 1      1199091.0   106895.0
# 2       198744.0     5668.0
# 3      1010330.0    92423.0
# 4       215527.0     4549.0
# ...          ...        ...
# 12289      329.0        0.0
# 12290      302.0        0.0
# 12291      351.0        2.0
# 12292      293.0        0.0
# 12293      290.0        3.0
#
#                                               background    premiered  \
# 0                                                    NaN          NaN
# 1      Fullmetal Alchemist: Brotherhood is an alterna...  Spring 2009
# 2       This is a fourth season of Gintama. In the ep...  Spring 2015
# 3      Steins;Gate is based on 5pb. and Nitroplus&#03...  Spring 2011
# 4      This is the second season of Gintama. In the e...  Spring 2011
# ...                                                  ...          ...
# 12289                                                NaN          NaN
# 12290                                                NaN          NaN
# 12291                                                NaN          NaN
# 12292                                                NaN          NaN
# 12293                                                NaN          NaN
#
#                        broadcast  \
# 0                            NaN
# 1         Sundays at 17:00 (JST)
# 2      Wednesdays at 18:00 (JST)
# 3      Wednesdays at 02:05 (JST)
# 4         Mondays at 18:00 (JST)
# ...                          ...
# 12289                        NaN
# 12290                        NaN
# 12291                        NaN
# 12292                        NaN
# 12293                        NaN
#
#                                                  related  \
# 0      {'Adaptation': [{'mal_id': 99314, 'type': 'man...
# 1      {'Adaptation': [{'mal_id': 25, 'type': 'manga'...
# 2      {'Adaptation': [{'mal_id': 44, 'type': 'manga'...
# 3      {'Adaptation': [{'mal_id': 17517, 'type': 'man...
# 4      {'Adaptation': [{'mal_id': 44, 'type': 'manga'...
# ...                                                  ...
# 12289                                                 []
# 12290                                                 []
# 12291  {'Sequel': [{'mal_id': 6133, 'type': 'anime', ...
# 12292  {'Prequel': [{'mal_id': 5621, 'type': 'anime',...
# 12293                                                 []
#
#                                                 producer  \
# 0      Kadokawa Shoten, Toho, Sound Team Don Juan, La...
# 1      Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                              TV Tokyo, Aniplex, Dentsu
# 3      Frontier Works, Media Factory, Movic, AT-X, Ka...
# 4      TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                  ...
# 12289                                                NaN
# 12290                                                NaN
# 12291                                                NaN
# 12292                                                NaN
# 12293                                                NaN
#
#                              licensor                 studio  \
# 0               Funimation, NYAV Post       CoMix Wave Films
# 1      Funimation, Aniplex of America                  Bones
# 2             Funimation, Crunchyroll  Bandai Namco Pictures
# 3                          Funimation              White Fox
# 4                                 NaN                Sunrise
# ...                               ...                    ...
# 12289                             NaN                    NaN
# 12290                             NaN                    NaN
# 12291                             NaN                    NaN
# 12292                             NaN                    NaN
# 12293                             NaN                    NaN
#
#                                                  genre_y  \
# 0                   Supernatural, Drama, Romance, School
# 1      Action, Military, Adventure, Comedy, Drama, Ma...
# 2      Action, Comedy, Historical, Parody, Samurai, S...
# 3                                       Thriller, Sci-Fi
# 4      Action, Sci-Fi, Comedy, Historical, Parody, Sa...
# ...                                                  ...
# 12289                                             Hentai
# 12290                                             Hentai
# 12291                                             Hentai
# 12292                                             Hentai
# 12293                                             Hentai
#
#                                            opening_theme  \
# 0                    ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 1      ['#1: "again" by YUI (eps 1-14)', '#2: "Hologr...
# 2      ['#1: "DAY×DAY" by BLUE ENCOUNT (eps 1-12)', '...
# 3               ['"Hacking to the Gate" by Kanako Itou']
# 4      ['#1: "Tougenkyou Alien (桃源郷エイリアン)" by serial ...
# ...                                                  ...
# 12289                                                 []
# 12290                                                 []
# 12291                                                 []
# 12292                                                 []
# 12293                                                 []
#
#                                             ending_theme  num_ratings
# 0               ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0
# 1      ['#1: "Uso (嘘)" by SID (eps 1-14)', '#2: "LET ...      21494.0
# 2      ['#1: "DESTINY" by Negoto (eps 1-12)', '#2: "S...       1188.0
# 3      ['#1: "Toki Tsukasadoru Juuni no Meiyaku (刻司ル十...      17151.0
# 4      ['#1: "Samurai Heart (Some Like It Hot!!)" by ...       3115.0
# ...                                                  ...          ...
# 12289                                                 []          2.0
# 12290                                                 []          2.0
# 12291                                                 []          1.0
# 12292                                                 []          1.0
# 12293                                                 []          NaN
#
# [12294 rows x 38 columns]

# %%
anime_full['type_x'].unique()
#only care about Movie & TV, what is OVA & ONA?
# Out:
# array(['Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA', nan], dtype=object)

# %%
anime_full['rating_y'].unique()
# Out:
# array(['PG-13 - Teens 13 or older', 'R - 17+ (violence & profanity)',
#        'PG - Children', 'G - All Ages', 'R+ - Mild Nudity', 'None', nan,
#        'Rx - Hentai'], dtype=object)

# %%
producers = anime_full['producer'].nunique()
licensers = anime_full['licensor'].nunique()
studio = anime_full['studio'].nunique()
print(f'Producers: {producers}, Licensors: {licensers}, studio: {studio}')
# Out:
# Producers: 3004, Licensors: 190, studio: 694

# %%
anime_full['licensor'].unique()[0]
#Licensors are lists of multiple licensors, may be worth while to blow up
# Out:
# 'Funimation, NYAV Post'

# %%
anime_full['producer'].unique()[0]
#Same for producers, may need to blow up
# Out:
# 'Kadokawa Shoten, Toho, Sound Team Don Juan, Lawson HMV Entertainment, Amuse, East Japan Marketing &amp; Communications'

# %%
anime_full['studio'].unique()[0]
#Only one studio per anime, can visualize ratings per studio
# Out:
# 'CoMix Wave Films'

# %%
anime_full['background']
#Most background cells are empty. Bummer. Cannot use NLP to analyze.
# Out:
# 0                                                      NaN
# 1        Fullmetal Alchemist: Brotherhood is an alterna...
# 2         This is a fourth season of Gintama. In the ep...
# 3        Steins;Gate is based on 5pb. and Nitroplus&#03...
# 4        This is the second season of Gintama. In the e...
#                                ...
# 12289                                                  NaN
# 12290                                                  NaN
# 12291                                                  NaN
# 12292                                                  NaN
# 12293                                                  NaN
# Name: background, Length: 12294, dtype: object

# %%
anime_full['image_url'][0]
# Out:
# 'https://myanimelist.cdn-dena.com/images/anime/5/87048.jpg'

# %%
anime_full[['name','title','title_japanese','title_english','title_synonyms']].isnull().sum()
#drop the unneccessary additional titles
# Out:
# name                 0
# title               17
# title_japanese      40
# title_english     7217
# title_synonyms    4537
# dtype: int64

# %%
(anime_full.isnull().sum()/len(anime_full)).sort_values(ascending=False)
# Out:
# background        0.924597
# licensor          0.736213
# premiered         0.698878
# broadcast         0.691069
# title_english     0.587034
# producer          0.390678
# studio            0.375874
# title_synonyms    0.369042
# num_ratings       0.192614
# rank              0.099723
# rating_x          0.018708
# image_url         0.007077
# genre_x           0.005043
# genre_y           0.004799
# title_japanese    0.003254
# type_x            0.002034
# status            0.001383
# title             0.001383
# type_y            0.001383
# source            0.001383
# episodes_y        0.001383
# aired             0.001383
# airing            0.001383
# aired_string      0.001383
# ending_theme      0.001383
# duration          0.001383
# rating_y          0.001383
# score             0.001383
# scored_by         0.001383
# popularity        0.001383
# members_y         0.001383
# favorites         0.001383
# related           0.001383
# opening_theme     0.001383
# members_x         0.000000
# episodes_x        0.000000
# name              0.000000
# anime_id          0.000000
# dtype: float64

# %%
anime_full[['type_x','type_y']].isnull().sum() #keep y
anime_full[['episodes_x','episodes_y']].isnull().sum() #keep x
anime_full[['status','airing']].isnull().sum() #Drop airing, contains redundant info
anime_full[['rating_x', 'members_x','score','scored_by', 'members_y']] #drop all score columns from meta_df
anime_full[['genre_x','genre_y']].isnull().sum() #drop genre_x
anime_full[['opening_theme','ending_theme']].iloc[1,:] # could we do some sort of NLP on the opening/ending themes?
# Out:
# opening_theme    ['#1: "again" by YUI (eps 1-14)', '#2: "Hologr...
# ending_theme     ['#1: "Uso (嘘)" by SID (eps 1-14)', '#2: "LET ...
# Name: 1, dtype: object

# %%
anime_full['related'][0]
#not sure what this is, delete.
# Out:
# "{'Adaptation': [{'mal_id': 99314, 'type': 'manga', 'url': 'https://myanimelist.net/manga/99314/Kimi_no_Na_wa', 'title': 'Kimi no Na wa.'}, {'mal_id': 111747, 'type': 'manga', 'url': 'https://myanimelist.net/manga/111747/Kimi_no_Na_wa', 'title': 'Kimi no Na wa.'}], 'Other': [{'mal_id': 33902, 'type': 'anime', 'url': 'https://myanimelist.net/anime/33902/Suntory_Minami_Alps_no_Tennen_Mizu', 'title': 'Suntory Minami Alps no Tennen Mizu'}]}"

# %%
anime_full[['aired_string','aired']]
# Out:
#                       aired_string                                       aired
# 0                     Aug 26, 2016  {'from': '2016-08-26', 'to': '2016-08-26'}
# 1       Apr 5, 2009 to Jul 4, 2010  {'from': '2009-04-05', 'to': '2010-07-04'}
# 2      Apr 8, 2015 to Mar 30, 2016  {'from': '2015-04-08', 'to': '2016-03-30'}
# 3      Apr 6, 2011 to Sep 14, 2011  {'from': '2011-04-06', 'to': '2011-09-14'}
# 4      Apr 4, 2011 to Mar 26, 2012  {'from': '2011-04-04', 'to': '2012-03-26'}
# ...                            ...                                         ...
# 12289                 Oct 26, 2001  {'from': '2001-10-26', 'to': '2001-10-26'}
# 12290                 Nov 18, 2000  {'from': '2000-11-18', 'to': '2000-11-18'}
# 12291   Dec 5, 1989 to Jun 5, 1990  {'from': '1989-12-05', 'to': '1990-06-05'}
# 12292                  Mar 8, 1991  {'from': '1991-03-08', 'to': '1991-03-08'}
# 12293                 Sep 24, 1971  {'from': '1971-09-24', 'to': '1971-09-24'}
#
# [12294 rows x 2 columns]

# %% [markdown]
# ## Final Cleaning of anime_df

# %%
anime_full = anime_full.drop(columns=['title','title_japanese','title_english','title_synonyms', 'type_x',
                                      'episodes_y', 'airing', 'score','scored_by', 'members_y', 'background',
                                     'licensor', 'premiered', 'broadcast', 'related', 'genre_x', 'aired_string'])
anime_full
# Out:
#        anime_id                                               name episodes_x  \
# 0         32281                                     Kimi no Na wa.          1
# 1          5114                   Fullmetal Alchemist: Brotherhood         64
# 2         28977                                           Gintama°         51
# 3          9253                                        Steins;Gate         24
# 4          9969                                      Gintama&#039;         51
# ...         ...                                                ...        ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami          1
# 12290      5543                                        Under World          1
# 12291      5621                     Violence Gekiga David no Hoshi          4
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...          1
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!          1
#
#        rating_x  members_x                                          image_url  \
# 0          9.37     200630  https://myanimelist.cdn-dena.com/images/anime/...
# 1          9.26     793665  https://myanimelist.cdn-dena.com/images/anime/...
# 2          9.25     114262  https://myanimelist.cdn-dena.com/images/anime/...
# 3          9.17     673572  https://myanimelist.cdn-dena.com/images/anime/...
# 4          9.16     151266  https://myanimelist.cdn-dena.com/images/anime/...
# ...         ...        ...                                                ...
# 12289      4.15        211  https://myanimelist.cdn-dena.com/images/anime/...
# 12290      4.28        183  https://myanimelist.cdn-dena.com/images/anime/...
# 12291      4.88        219  https://myanimelist.cdn-dena.com/images/anime/...
# 12292      4.98        175  https://myanimelist.cdn-dena.com/images/anime/...
# 12293      5.46        142  https://myanimelist.cdn-dena.com/images/anime/...
#
#       type_y        source           status  \
# 0      Movie      Original  Finished Airing
# 1         TV         Manga  Finished Airing
# 2         TV         Manga  Finished Airing
# 3         TV  Visual novel  Finished Airing
# 4         TV         Manga  Finished Airing
# ...      ...           ...              ...
# 12289    OVA       Unknown  Finished Airing
# 12290    OVA       Unknown  Finished Airing
# 12291    OVA       Unknown  Finished Airing
# 12292    OVA       Unknown  Finished Airing
# 12293  Movie       Unknown  Finished Airing
#
#                                             aired         duration  \
# 0      {'from': '2016-08-26', 'to': '2016-08-26'}    1 hr. 46 min.
# 1      {'from': '2009-04-05', 'to': '2010-07-04'}  24 min. per ep.
# 2      {'from': '2015-04-08', 'to': '2016-03-30'}  24 min. per ep.
# 3      {'from': '2011-04-06', 'to': '2011-09-14'}  24 min. per ep.
# 4      {'from': '2011-04-04', 'to': '2012-03-26'}  24 min. per ep.
# ...                                           ...              ...
# 12289  {'from': '2001-10-26', 'to': '2001-10-26'}          30 min.
# 12290  {'from': '2000-11-18', 'to': '2000-11-18'}     1 hr. 4 min.
# 12291  {'from': '1989-12-05', 'to': '1990-06-05'}  45 min. per ep.
# 12292  {'from': '1991-03-08', 'to': '1991-03-08'}          45 min.
# 12293  {'from': '1971-09-24', 'to': '1971-09-24'}    1 hr. 41 min.
#
#                              rating_y  rank  popularity  favorites  \
# 0           PG-13 - Teens 13 or older   2.0        33.0    34912.0
# 1      R - 17+ (violence & profanity)   1.0         4.0   106895.0
# 2      R - 17+ (violence & profanity)   3.0       383.0     5668.0
# 3           PG-13 - Teens 13 or older   5.0         8.0    92423.0
# 4           PG-13 - Teens 13 or older   7.0       342.0     4549.0
# ...                               ...   ...         ...        ...
# 12289                     Rx - Hentai   NaN     10297.0        0.0
# 12290                     Rx - Hentai   NaN     10456.0        0.0
# 12291                     Rx - Hentai   NaN     10164.0        2.0
# 12292                     Rx - Hentai   NaN     10510.0        0.0
# 12293                     Rx - Hentai   NaN     10534.0        3.0
#
#                                                 producer  \
# 0      Kadokawa Shoten, Toho, Sound Team Don Juan, La...
# 1      Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                              TV Tokyo, Aniplex, Dentsu
# 3      Frontier Works, Media Factory, Movic, AT-X, Ka...
# 4      TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                  ...
# 12289                                                NaN
# 12290                                                NaN
# 12291                                                NaN
# 12292                                                NaN
# 12293                                                NaN
#
#                       studio  \
# 0           CoMix Wave Films
# 1                      Bones
# 2      Bandai Namco Pictures
# 3                  White Fox
# 4                    Sunrise
# ...                      ...
# 12289                    NaN
# 12290                    NaN
# 12291                    NaN
# 12292                    NaN
# 12293                    NaN
#
#                                                  genre_y  \
# 0                   Supernatural, Drama, Romance, School
# 1      Action, Military, Adventure, Comedy, Drama, Ma...
# 2      Action, Comedy, Historical, Parody, Samurai, S...
# 3                                       Thriller, Sci-Fi
# 4      Action, Sci-Fi, Comedy, Historical, Parody, Sa...
# ...                                                  ...
# 12289                                             Hentai
# 12290                                             Hentai
# 12291                                             Hentai
# 12292                                             Hentai
# 12293                                             Hentai
#
#                                            opening_theme  \
# 0                    ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 1      ['#1: "again" by YUI (eps 1-14)', '#2: "Hologr...
# 2      ['#1: "DAY×DAY" by BLUE ENCOUNT (eps 1-12)', '...
# 3               ['"Hacking to the Gate" by Kanako Itou']
# 4      ['#1: "Tougenkyou Alien (桃源郷エイリアン)" by serial ...
# ...                                                  ...
# 12289                                                 []
# 12290                                                 []
# 12291                                                 []
# 12292                                                 []
# 12293                                                 []
#
#                                             ending_theme  num_ratings
# 0               ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0
# 1      ['#1: "Uso (嘘)" by SID (eps 1-14)', '#2: "LET ...      21494.0
# 2      ['#1: "DESTINY" by Negoto (eps 1-12)', '#2: "S...       1188.0
# 3      ['#1: "Toki Tsukasadoru Juuni no Meiyaku (刻司ル十...      17151.0
# 4      ['#1: "Samurai Heart (Some Like It Hot!!)" by ...       3115.0
# ...                                                  ...          ...
# 12289                                                 []          2.0
# 12290                                                 []          2.0
# 12291                                                 []          1.0
# 12292                                                 []          1.0
# 12293                                                 []          NaN
#
# [12294 rows x 21 columns]

# %%
anime_full = anime_full.rename(columns={'rating_x': 'avg_rating','rating_y': 'rating_type', 'genre_y':'genre', 
                                        'members_x': 'members', 'episodes_x':'episodes', 'type_y':'type'})
anime_full
# Out:
#        anime_id                                               name episodes  \
# 0         32281                                     Kimi no Na wa.        1
# 1          5114                   Fullmetal Alchemist: Brotherhood       64
# 2         28977                                           Gintama°       51
# 3          9253                                        Steins;Gate       24
# 4          9969                                      Gintama&#039;       51
# ...         ...                                                ...      ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami        1
# 12290      5543                                        Under World        1
# 12291      5621                     Violence Gekiga David no Hoshi        4
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...        1
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!        1
#
#        avg_rating  members                                          image_url  \
# 0            9.37   200630  https://myanimelist.cdn-dena.com/images/anime/...
# 1            9.26   793665  https://myanimelist.cdn-dena.com/images/anime/...
# 2            9.25   114262  https://myanimelist.cdn-dena.com/images/anime/...
# 3            9.17   673572  https://myanimelist.cdn-dena.com/images/anime/...
# 4            9.16   151266  https://myanimelist.cdn-dena.com/images/anime/...
# ...           ...      ...                                                ...
# 12289        4.15      211  https://myanimelist.cdn-dena.com/images/anime/...
# 12290        4.28      183  https://myanimelist.cdn-dena.com/images/anime/...
# 12291        4.88      219  https://myanimelist.cdn-dena.com/images/anime/...
# 12292        4.98      175  https://myanimelist.cdn-dena.com/images/anime/...
# 12293        5.46      142  https://myanimelist.cdn-dena.com/images/anime/...
#
#         type        source           status  \
# 0      Movie      Original  Finished Airing
# 1         TV         Manga  Finished Airing
# 2         TV         Manga  Finished Airing
# 3         TV  Visual novel  Finished Airing
# 4         TV         Manga  Finished Airing
# ...      ...           ...              ...
# 12289    OVA       Unknown  Finished Airing
# 12290    OVA       Unknown  Finished Airing
# 12291    OVA       Unknown  Finished Airing
# 12292    OVA       Unknown  Finished Airing
# 12293  Movie       Unknown  Finished Airing
#
#                                             aired         duration  \
# 0      {'from': '2016-08-26', 'to': '2016-08-26'}    1 hr. 46 min.
# 1      {'from': '2009-04-05', 'to': '2010-07-04'}  24 min. per ep.
# 2      {'from': '2015-04-08', 'to': '2016-03-30'}  24 min. per ep.
# 3      {'from': '2011-04-06', 'to': '2011-09-14'}  24 min. per ep.
# 4      {'from': '2011-04-04', 'to': '2012-03-26'}  24 min. per ep.
# ...                                           ...              ...
# 12289  {'from': '2001-10-26', 'to': '2001-10-26'}          30 min.
# 12290  {'from': '2000-11-18', 'to': '2000-11-18'}     1 hr. 4 min.
# 12291  {'from': '1989-12-05', 'to': '1990-06-05'}  45 min. per ep.
# 12292  {'from': '1991-03-08', 'to': '1991-03-08'}          45 min.
# 12293  {'from': '1971-09-24', 'to': '1971-09-24'}    1 hr. 41 min.
#
#                           rating_type  rank  popularity  favorites  \
# 0           PG-13 - Teens 13 or older   2.0        33.0    34912.0
# 1      R - 17+ (violence & profanity)   1.0         4.0   106895.0
# 2      R - 17+ (violence & profanity)   3.0       383.0     5668.0
# 3           PG-13 - Teens 13 or older   5.0         8.0    92423.0
# 4           PG-13 - Teens 13 or older   7.0       342.0     4549.0
# ...                               ...   ...         ...        ...
# 12289                     Rx - Hentai   NaN     10297.0        0.0
# 12290                     Rx - Hentai   NaN     10456.0        0.0
# 12291                     Rx - Hentai   NaN     10164.0        2.0
# 12292                     Rx - Hentai   NaN     10510.0        0.0
# 12293                     Rx - Hentai   NaN     10534.0        3.0
#
#                                                 producer  \
# 0      Kadokawa Shoten, Toho, Sound Team Don Juan, La...
# 1      Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                              TV Tokyo, Aniplex, Dentsu
# 3      Frontier Works, Media Factory, Movic, AT-X, Ka...
# 4      TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                  ...
# 12289                                                NaN
# 12290                                                NaN
# 12291                                                NaN
# 12292                                                NaN
# 12293                                                NaN
#
#                       studio  \
# 0           CoMix Wave Films
# 1                      Bones
# 2      Bandai Namco Pictures
# 3                  White Fox
# 4                    Sunrise
# ...                      ...
# 12289                    NaN
# 12290                    NaN
# 12291                    NaN
# 12292                    NaN
# 12293                    NaN
#
#                                                    genre  \
# 0                   Supernatural, Drama, Romance, School
# 1      Action, Military, Adventure, Comedy, Drama, Ma...
# 2      Action, Comedy, Historical, Parody, Samurai, S...
# 3                                       Thriller, Sci-Fi
# 4      Action, Sci-Fi, Comedy, Historical, Parody, Sa...
# ...                                                  ...
# 12289                                             Hentai
# 12290                                             Hentai
# 12291                                             Hentai
# 12292                                             Hentai
# 12293                                             Hentai
#
#                                            opening_theme  \
# 0                    ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 1      ['#1: "again" by YUI (eps 1-14)', '#2: "Hologr...
# 2      ['#1: "DAY×DAY" by BLUE ENCOUNT (eps 1-12)', '...
# 3               ['"Hacking to the Gate" by Kanako Itou']
# 4      ['#1: "Tougenkyou Alien (桃源郷エイリアン)" by serial ...
# ...                                                  ...
# 12289                                                 []
# 12290                                                 []
# 12291                                                 []
# 12292                                                 []
# 12293                                                 []
#
#                                             ending_theme  num_ratings
# 0               ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0
# 1      ['#1: "Uso (嘘)" by SID (eps 1-14)', '#2: "LET ...      21494.0
# 2      ['#1: "DESTINY" by Negoto (eps 1-12)', '#2: "S...       1188.0
# 3      ['#1: "Toki Tsukasadoru Juuni no Meiyaku (刻司ル十...      17151.0
# 4      ['#1: "Samurai Heart (Some Like It Hot!!)" by ...       3115.0
# ...                                                  ...          ...
# 12289                                                 []          2.0
# 12290                                                 []          2.0
# 12291                                                 []          1.0
# 12292                                                 []          1.0
# 12293                                                 []          NaN
#
# [12294 rows x 21 columns]

# %%
anime_full[anime_full['num_ratings'].isnull()]
# Out:
#        anime_id                                            name episodes  \
# 31        32983                           Natsume Yuujinchou Go       13
# 62        32995                                  Yuri!!! on Ice       12
# 74           21                                       One Piece  Unknown
# 76        31933  JoJo no Kimyou na Bouken: Diamond wa Kudakenai       39
# 140       10937                  Mobile Suit Gundam: The Origin        6
# ...         ...                                             ...      ...
# 12282     34388                 Shikkoku no Shaga The Animation  Unknown
# 12283     29992                            Silent Chaser Kagami        1
# 12284     26031                              Super Erotic Anime        2
# 12285     34399                                Taimanin Asagi 3  Unknown
# 12293     26081                Yasuji no Pornorama: Yacchimae!!        1
#
#        avg_rating  members                                          image_url  \
# 31           8.76    38865  https://myanimelist.cdn-dena.com/images/anime/...
# 62           8.61   103178  https://myanimelist.cdn-dena.com/images/anime/...
# 74           8.58   504862  https://myanimelist.cdn-dena.com/images/anime/...
# 76           8.57    74074  https://myanimelist.cdn-dena.com/images/anime/...
# 140          8.42    15420  https://myanimelist.cdn-dena.com/images/anime/...
# ...           ...      ...                                                ...
# 12282         NaN      195  https://myanimelist.cdn-dena.com/images/anime/...
# 12283        4.95      112  https://myanimelist.cdn-dena.com/images/anime/...
# 12284        4.45      118  https://myanimelist.cdn-dena.com/images/anime/...
# 12285         NaN      485  https://myanimelist.cdn-dena.com/images/anime/...
# 12293        5.46      142  https://myanimelist.cdn-dena.com/images/anime/...
#
#         type        source            status  \
# 31        TV         Manga   Finished Airing
# 62        TV      Original   Finished Airing
# 74        TV         Manga  Currently Airing
# 76        TV         Manga   Finished Airing
# 140      OVA         Manga   Finished Airing
# ...      ...           ...               ...
# 12282    OVA      Original  Currently Airing
# 12283    OVA       Unknown   Finished Airing
# 12284    OVA       Unknown   Finished Airing
# 12285    OVA  Visual novel  Currently Airing
# 12293  Movie       Unknown   Finished Airing
#
#                                             aired              duration  \
# 31     {'from': '2016-10-05', 'to': '2016-12-21'}       23 min. per ep.
# 62     {'from': '2016-10-06', 'to': '2016-12-22'}       23 min. per ep.
# 74             {'from': '1999-10-20', 'to': None}               24 min.
# 76     {'from': '2016-04-02', 'to': '2016-12-24'}       23 min. per ep.
# 140    {'from': '2015-04-24', 'to': '2018-05-05'}  1 hr. 3 min. per ep.
# ...                                           ...                   ...
# 12282          {'from': '2017-02-24', 'to': None}               30 min.
# 12283  {'from': '2000-08-21', 'to': '2000-08-21'}               30 min.
# 12284  {'from': '1985-10-09', 'to': '1985-10-17'}       27 min. per ep.
# 12285          {'from': '2016-12-23', 'to': None}               30 min.
# 12293  {'from': '1971-09-24', 'to': '1971-09-24'}         1 hr. 41 min.
#
#                           rating_type   rank  popularity  favorites  \
# 31          PG-13 - Teens 13 or older   63.0      1038.0      459.0
# 62          PG-13 - Teens 13 or older  339.0       238.0    11140.0
# 74          PG-13 - Teens 13 or older   91.0        35.0    69760.0
# 76     R - 17+ (violence & profanity)   64.0       432.0     7188.0
# 140                  R+ - Mild Nudity  128.0      2189.0      240.0
# ...                               ...    ...         ...        ...
# 12282                     Rx - Hentai    NaN      5491.0       37.0
# 12283                     Rx - Hentai    NaN     10978.0        0.0
# 12284                     Rx - Hentai    NaN     11020.0        1.0
# 12285                     Rx - Hentai    NaN      6438.0       15.0
# 12293                     Rx - Hentai    NaN     10534.0        3.0
#
#                                                 producer            studio  \
# 31       TV Tokyo, Aniplex, Nihon Ad Systems, Hakusensha             Shuka
# 62     Dentsu, TV Asahi, Movic, Avex Pictures, CIC, C...             MAPPA
# 74                                Fuji TV, TAP, Shueisha    Toei Animation
# 76     Warner Bros., KlockWorx, Medicos Entertainment...  David Production
# 140                                                  NaN           Sunrise
# ...                                                  ...               ...
# 12282                                     Pink Pineapple             Seven
# 12283                                                NaN               NaN
# 12284                                                NaN               NaN
# 12285                            ZIZ Entertainment (ZIZ)  Studio Eromatick
# 12293                                                NaN               NaN
#
#                                                    genre  \
# 31     Slice of Life, Supernatural, Drama, Fantasy, S...
# 62                                        Comedy, Sports
# 74     Action, Adventure, Comedy, Super Power, Drama,...
# 76     Action, Adventure, Comedy, Supernatural, Drama...
# 140      Action, Military, Sci-Fi, Space, Mecha, Shounen
# ...                                                  ...
# 12282                                             Hentai
# 12283                                             Hentai
# 12284                                             Hentai
# 12285                       Demons, Hentai, Supernatural
# 12293                                             Hentai
#
#                                            opening_theme  \
# 31       ['"Takarabako (タカラバコ)" by Sasanomaly (ササノマリイ)']
# 62                   ['"History Maker" by Dean Fujioka']
# 74     ['#01: "We Are! (ウィーアー!)" by Hiroshi Kitadani ...
# 76     ['#1: "Crazy Noisy Bizarre Town" by THE DU (ep...
# 140                                                   []
# ...                                                  ...
# 12282                                                 []
# 12283                                                 []
# 12284                                                 []
# 12285                                                 []
# 12293                                                 []
#
#                                             ending_theme  num_ratings
# 31                       ['"Akane Sasu (茜さす)" by Aimer']          NaN
# 62     ['"You Only Live Once" by YURI!!! on ICE feat....          NaN
# 74     ['#01: "memories" by Maki Otsuki (eps 1-30)', ...          NaN
# 76     ['#1: "I WANT YOU" by Savage Garden (eps 2-7, ...          NaN
# 140    ['#1: "Hoshikuzu no Sunadokei (星屑の砂時計)" by Tak...          NaN
# ...                                                  ...          ...
# 12282                      ['"Treasures" by Naoka Wada']          NaN
# 12283                                                 []          NaN
# 12284                                                 []          NaN
# 12285         ['"Catharsis no Yume (カタルシスの夢)" by Maiko']          NaN
# 12293                                                 []          NaN
#
# [2368 rows x 21 columns]

# %%
def weighted_rating(x):
    m = x['members'].quantile(0.80)
    C = x['avg_rating'].mean()
    v = x['members']
    R = x['avg_rating']
    # Compute the weighted score
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
anime_full = pd.concat([anime_full, weighted_rating(anime_full)], axis=1)
anime_full = anime_full.rename(columns={0: 'weighted_rating'})
anime_full
# Out:
#        anime_id                                               name episodes  \
# 0         32281                                     Kimi no Na wa.        1
# 1          5114                   Fullmetal Alchemist: Brotherhood       64
# 2         28977                                           Gintama°       51
# 3          9253                                        Steins;Gate       24
# 4          9969                                      Gintama&#039;       51
# ...         ...                                                ...      ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami        1
# 12290      5543                                        Under World        1
# 12291      5621                     Violence Gekiga David no Hoshi        4
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...        1
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!        1
#
#        avg_rating  members                                          image_url  \
# 0            9.37   200630  https://myanimelist.cdn-dena.com/images/anime/...
# 1            9.26   793665  https://myanimelist.cdn-dena.com/images/anime/...
# 2            9.25   114262  https://myanimelist.cdn-dena.com/images/anime/...
# 3            9.17   673572  https://myanimelist.cdn-dena.com/images/anime/...
# 4            9.16   151266  https://myanimelist.cdn-dena.com/images/anime/...
# ...           ...      ...                                                ...
# 12289        4.15      211  https://myanimelist.cdn-dena.com/images/anime/...
# 12290        4.28      183  https://myanimelist.cdn-dena.com/images/anime/...
# 12291        4.88      219  https://myanimelist.cdn-dena.com/images/anime/...
# 12292        4.98      175  https://myanimelist.cdn-dena.com/images/anime/...
# 12293        5.46      142  https://myanimelist.cdn-dena.com/images/anime/...
#
#         type        source           status  \
# 0      Movie      Original  Finished Airing
# 1         TV         Manga  Finished Airing
# 2         TV         Manga  Finished Airing
# 3         TV  Visual novel  Finished Airing
# 4         TV         Manga  Finished Airing
# ...      ...           ...              ...
# 12289    OVA       Unknown  Finished Airing
# 12290    OVA       Unknown  Finished Airing
# 12291    OVA       Unknown  Finished Airing
# 12292    OVA       Unknown  Finished Airing
# 12293  Movie       Unknown  Finished Airing
#
#                                             aired         duration  \
# 0      {'from': '2016-08-26', 'to': '2016-08-26'}    1 hr. 46 min.
# 1      {'from': '2009-04-05', 'to': '2010-07-04'}  24 min. per ep.
# 2      {'from': '2015-04-08', 'to': '2016-03-30'}  24 min. per ep.
# 3      {'from': '2011-04-06', 'to': '2011-09-14'}  24 min. per ep.
# 4      {'from': '2011-04-04', 'to': '2012-03-26'}  24 min. per ep.
# ...                                           ...              ...
# 12289  {'from': '2001-10-26', 'to': '2001-10-26'}          30 min.
# 12290  {'from': '2000-11-18', 'to': '2000-11-18'}     1 hr. 4 min.
# 12291  {'from': '1989-12-05', 'to': '1990-06-05'}  45 min. per ep.
# 12292  {'from': '1991-03-08', 'to': '1991-03-08'}          45 min.
# 12293  {'from': '1971-09-24', 'to': '1971-09-24'}    1 hr. 41 min.
#
#                           rating_type  rank  popularity  favorites  \
# 0           PG-13 - Teens 13 or older   2.0        33.0    34912.0
# 1      R - 17+ (violence & profanity)   1.0         4.0   106895.0
# 2      R - 17+ (violence & profanity)   3.0       383.0     5668.0
# 3           PG-13 - Teens 13 or older   5.0         8.0    92423.0
# 4           PG-13 - Teens 13 or older   7.0       342.0     4549.0
# ...                               ...   ...         ...        ...
# 12289                     Rx - Hentai   NaN     10297.0        0.0
# 12290                     Rx - Hentai   NaN     10456.0        0.0
# 12291                     Rx - Hentai   NaN     10164.0        2.0
# 12292                     Rx - Hentai   NaN     10510.0        0.0
# 12293                     Rx - Hentai   NaN     10534.0        3.0
#
#                                                 producer  \
# 0      Kadokawa Shoten, Toho, Sound Team Don Juan, La...
# 1      Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                              TV Tokyo, Aniplex, Dentsu
# 3      Frontier Works, Media Factory, Movic, AT-X, Ka...
# 4      TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                  ...
# 12289                                                NaN
# 12290                                                NaN
# 12291                                                NaN
# 12292                                                NaN
# 12293                                                NaN
#
#                       studio  \
# 0           CoMix Wave Films
# 1                      Bones
# 2      Bandai Namco Pictures
# 3                  White Fox
# 4                    Sunrise
# ...                      ...
# 12289                    NaN
# 12290                    NaN
# 12291                    NaN
# 12292                    NaN
# 12293                    NaN
#
#                                                    genre  \
# 0                   Supernatural, Drama, Romance, School
# 1      Action, Military, Adventure, Comedy, Drama, Ma...
# 2      Action, Comedy, Historical, Parody, Samurai, S...
# 3                                       Thriller, Sci-Fi
# 4      Action, Sci-Fi, Comedy, Historical, Parody, Sa...
# ...                                                  ...
# 12289                                             Hentai
# 12290                                             Hentai
# 12291                                             Hentai
# 12292                                             Hentai
# 12293                                             Hentai
#
#                                            opening_theme  \
# 0                    ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 1      ['#1: "again" by YUI (eps 1-14)', '#2: "Hologr...
# 2      ['#1: "DAY×DAY" by BLUE ENCOUNT (eps 1-12)', '...
# 3               ['"Hacking to the Gate" by Kanako Itou']
# 4      ['#1: "Tougenkyou Alien (桃源郷エイリアン)" by serial ...
# ...                                                  ...
# 12289                                                 []
# 12290                                                 []
# 12291                                                 []
# 12292                                                 []
# 12293                                                 []
#
#                                             ending_theme  num_ratings  \
# 0               ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0
# 1      ['#1: "Uso (嘘)" by SID (eps 1-14)', '#2: "LET ...      21494.0
# 2      ['#1: "DESTINY" by Negoto (eps 1-12)', '#2: "S...       1188.0
# 3      ['#1: "Toki Tsukasadoru Juuni no Meiyaku (刻司ル十...      17151.0
# 4      ['#1: "Samurai Heart (Some Like It Hot!!)" by ...       3115.0
# ...                                                  ...          ...
# 12289                                                 []          2.0
# 12290                                                 []          2.0
# 12291                                                 []          1.0
# 12292                                                 []          1.0
# 12293                                                 []          NaN
#
#        weighted_rating
# 0             9.169377
# 1             9.208548
# 2             8.929129
# 3             9.111525
# 4             8.918657
# ...                ...
# 12289         6.441523
# 12290         6.447341
# 12291         6.450864
# 12292         6.456597
# 12293         6.464351
#
# [12294 rows x 22 columns]

# %% [markdown]
# ## Import the clean anime_full

# %%
from src.data_funcs import *
anime_df, rating_df, anime_meta, users_meta = import_data()
anime_full = full_anime_df(rating_df, anime_df, anime_meta)
anime_full
# Out:
#        anime_id                                               name episodes  \
# 0         32281                                     Kimi No Na Wa.        1
# 1          5114                   Fullmetal Alchemist: Brotherhood       64
# 2         28977                                           Gintama°       51
# 3          9253                                        Steins;Gate       24
# 4          9969                                      Gintama&#039;       51
# ...         ...                                                ...      ...
# 12289      9316       Toushindai My Lover: Minami Tai Mecha-Minami        1
# 12290      5543                                        Under World        1
# 12291      5621                     Violence Gekiga David No Hoshi        4
# 12292      6133  Violence Gekiga Shin David No Hoshi: Inma Dens...        1
# 12293     26081                   Yasuji No Pornorama: Yacchimae!!        1
#
#        avg_rating  members                     title_english  \
# 0            9.37   200630                        Your Name.
# 1            9.26   793665  Fullmetal Alchemist: Brotherhood
# 2            9.25   114262                  Gintama Season 4
# 3            9.17   673572                       Steins;Gate
# 4            9.16   151266                  Gintama Season 2
# ...           ...      ...                               ...
# 12289        4.15      211                               NaN
# 12290        4.28      183                               NaN
# 12291        4.88      219             Beautiful Girl Hunter
# 12292        4.98      175                               NaN
# 12293        5.46      142                               NaN
#
#                                                image_url   type        source  \
# 0      <img src="https://cdn.myanimelist.net/images/a...  Movie      Original
# 1      <img src="https://cdn.myanimelist.net/images/a...     TV         Manga
# 2      <img src="https://cdn.myanimelist.net/images/a...     TV         Manga
# 3      <img src="https://cdn.myanimelist.net/images/a...     TV  Visual novel
# 4      <img src="https://cdn.myanimelist.net/images/a...     TV         Manga
# ...                                                  ...    ...           ...
# 12289  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12290  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12291  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12292  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12293  <img src="https://cdn.myanimelist.net/images/a...  Movie       Unknown
#
#                 status                                       aired  \
# 0      Finished Airing  {'from': '2016-08-26', 'to': '2016-08-26'}
# 1      Finished Airing  {'from': '2009-04-05', 'to': '2010-07-04'}
# 2      Finished Airing  {'from': '2015-04-08', 'to': '2016-03-30'}
# 3      Finished Airing  {'from': '2011-04-06', 'to': '2011-09-14'}
# 4      Finished Airing  {'from': '2011-04-04', 'to': '2012-03-26'}
# ...                ...                                         ...
# 12289  Finished Airing  {'from': '2001-10-26', 'to': '2001-10-26'}
# 12290  Finished Airing  {'from': '2000-11-18', 'to': '2000-11-18'}
# 12291  Finished Airing  {'from': '1989-12-05', 'to': '1990-06-05'}
# 12292  Finished Airing  {'from': '1991-03-08', 'to': '1991-03-08'}
# 12293  Finished Airing  {'from': '1971-09-24', 'to': '1971-09-24'}
#
#               duration rating_type  rank  popularity  favorites  \
# 0        1 hr. 46 min.       PG-13   2.0        33.0    34912.0
# 1      24 min. per ep.           R   1.0         4.0   106895.0
# 2      24 min. per ep.           R   3.0       383.0     5668.0
# 3      24 min. per ep.       PG-13   5.0         8.0    92423.0
# 4      24 min. per ep.       PG-13   7.0       342.0     4549.0
# ...                ...         ...   ...         ...        ...
# 12289          30 min.          RX   NaN     10297.0        0.0
# 12290     1 hr. 4 min.          RX   NaN     10456.0        0.0
# 12291  45 min. per ep.          RX   NaN     10164.0        2.0
# 12292          45 min.          RX   NaN     10510.0        0.0
# 12293    1 hr. 41 min.          RX   NaN     10534.0        3.0
#
#                                                 producer  \
# 0      Kadokawa Shoten, Toho, Sound Team Don Juan, La...
# 1      Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                              TV Tokyo, Aniplex, Dentsu
# 3      Frontier Works, Media Factory, Movic, AT-X, Ka...
# 4      TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                  ...
# 12289                                            Unknown
# 12290                                            Unknown
# 12291                                            Unknown
# 12292                                            Unknown
# 12293                                            Unknown
#
#                       studio  \
# 0           CoMix Wave Films
# 1                      Bones
# 2      Bandai Namco Pictures
# 3                  White Fox
# 4                    Sunrise
# ...                      ...
# 12289                Unknown
# 12290                Unknown
# 12291                Unknown
# 12292                Unknown
# 12293                Unknown
#
#                                                    genre  \
# 0                   Supernatural, Drama, Romance, School
# 1      Action, Military, Adventure, Comedy, Drama, Ma...
# 2      Action, Comedy, Historical, Parody, Samurai, S...
# 3                                       Thriller, Sci-Fi
# 4      Action, Sci-Fi, Comedy, Historical, Parody, Sa...
# ...                                                  ...
# 12289                                             Hentai
# 12290                                             Hentai
# 12291                                             Hentai
# 12292                                             Hentai
# 12293                                             Hentai
#
#                                            opening_theme  \
# 0                    ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 1      ['#1: "again" by YUI (eps 1-14)', '#2: "Hologr...
# 2      ['#1: "DAY×DAY" by BLUE ENCOUNT (eps 1-12)', '...
# 3               ['"Hacking to the Gate" by Kanako Itou']
# 4      ['#1: "Tougenkyou Alien (桃源郷エイリアン)" by serial ...
# ...                                                  ...
# 12289                                                 []
# 12290                                                 []
# 12291                                                 []
# 12292                                                 []
# 12293                                                 []
#
#                                             ending_theme  num_ratings  \
# 0               ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0
# 1      ['#1: "Uso (嘘)" by SID (eps 1-14)', '#2: "LET ...      21494.0
# 2      ['#1: "DESTINY" by Negoto (eps 1-12)', '#2: "S...       1188.0
# 3      ['#1: "Toki Tsukasadoru Juuni no Meiyaku (刻司ル十...      17151.0
# 4      ['#1: "Samurai Heart (Some Like It Hot!!)" by ...       3115.0
# ...                                                  ...          ...
# 12289                                                 []          2.0
# 12290                                                 []          2.0
# 12291                                                 []          1.0
# 12292                                                 []          1.0
# 12293                                                 []          NaN
#
#        weighted_rating
# 0             9.169377
# 1             9.208548
# 2             8.929129
# 3             9.111525
# 4             8.918657
# ...                ...
# 12289         6.441523
# 12290         6.447341
# 12291         6.450864
# 12292         6.456597
# 12293         6.464351
#
# [12294 rows x 23 columns]

# %%
anime_full[['avg_rating','weighted_rating']].mean()
# Out:
# avg_rating         6.473902
# weighted_rating    6.654531
# dtype: float64

# %%
type(anime_full['aired'][0])
# Out:
# str

# %%
anime_full[anime_full['status'].isnull()]
# Out:
#        anime_id                                               name episodes  \
# 3548      32741  Girls Und Panzer Der Film: Fushou - Akiyama Yu...        2
# 4541       7839         Ufo Robo Grendizer: Akai Yuuhi No Taiketsu        1
# 5183       4388                            Mazinger Z Tai Dr. Hell        1
# 5217       5265                                           Mega Man       27
# 5461      10028                        Magic Knight Rayearth Omake        5
# 5762      32308                  Rilu Rilu Fairilu: Yousei No Door  Unknown
# 6509       8252                                Getter Robo (Movie)        1
# 7279      32588                                      Meow No Hoshi        1
# 8126      33655                   Alps No Shoujo Heidi? Chara Onji  Unknown
# 8667      31385                                  Ginga Shounen Tai       92
# 9124      31605  Kana Kana Kazoku: Kakusan Mare Bo ! 1-Wa-5-Wa ...        1
# 10140     22399                                   Saru Kani Gassen        1
# 10327     27499    Sore Ike! Anpanman: Anpanman To Kaizoku Lobster        1
# 10754     12091                                           X Bomber       25
# 10755     29133                                     X Bomber Pilot        1
# 10990     34485                                         Ganko-Chan  Unknown
# 12276     32713                              Original C-V-P Momoko        2
#
#        avg_rating  members title_english image_url type source status  ...  \
# 3548         6.94     1667           NaN       NaN  NaN    NaN    NaN  ...
# 4541         6.70      252           NaN       NaN  NaN    NaN    NaN  ...
# 5183         6.53      630           NaN       NaN  NaN    NaN    NaN  ...
# 5217         6.52     3263           NaN       NaN  NaN    NaN    NaN  ...
# 5461         6.45     1730           NaN       NaN  NaN    NaN    NaN  ...
# 5762         6.36     1293           NaN       NaN  NaN    NaN    NaN  ...
# 6509         6.08      527           NaN       NaN  NaN    NaN    NaN  ...
# 7279         5.58      212           NaN       NaN  NaN    NaN    NaN  ...
# 8126         6.79      277           NaN       NaN  NaN    NaN    NaN  ...
# 8667         6.38       79           NaN       NaN  NaN    NaN    NaN  ...
# 9124         5.11       44           NaN       NaN  NaN    NaN    NaN  ...
# 10140        5.23       62           NaN       NaN  NaN    NaN    NaN  ...
# 10327        5.50       70           NaN       NaN  NaN    NaN    NaN  ...
# 10754        5.94      199           NaN       NaN  NaN    NaN    NaN  ...
# 10755        4.28       77           NaN       NaN  NaN    NaN    NaN  ...
# 10990         NaN       11           NaN       NaN  NaN    NaN    NaN  ...
# 12276        4.00       66           NaN       NaN  NaN    NaN    NaN  ...
#
#       rank popularity favorites  producer  studio      genre opening_theme  \
# 3548   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 4541   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 5183   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 5217   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 5461   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 5762   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 6509   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 7279   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 8126   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 8667   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 9124   NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 10140  NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 10327  NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 10754  NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 10755  NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 10990  NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
# 12276  NaN        NaN       NaN       NaN     NaN  [Unknown]           NaN
#
#       ending_theme num_ratings weighted_rating
# 3548           NaN         9.0        6.520709
# 4541           NaN         6.0        6.477654
# 5183           NaN        15.0        6.476173
# 5217           NaN        76.0        6.482168
# 5461           NaN        36.0        6.471420
# 5762           NaN         NaN        6.464825
# 6509           NaN         8.0        6.460474
# 7279           NaN         4.0        6.461389
# 8126           NaN         NaN        6.479658
# 8667           NaN         NaN        6.473408
# 9124           NaN         NaN        6.469895
# 10140          NaN         NaN        6.468758
# 10327          NaN         NaN        6.469358
# 10754          NaN         1.0        6.466880
# 10755          NaN         1.0        6.462647
# 10990          NaN         NaN             NaN
# 12276          NaN         NaN        6.463016
#
# [17 rows x 23 columns]

# %%
anime_full['status'].unique()
# Out:
# array(['Finished Airing', 'Currently Airing', nan, 'Not yet aired'],
#       dtype=object)

# %%
plt.style.use('ggplot')

fig, ax = plt.subplots(1,3, figsize=(16,3))
ax[0].hist(anime_full['avg_rating'],bins=100)
ax[0].set_xlabel('Average Ratings from 1-10 in anime_meta')
ax[1].hist(anime_full['weighted_rating'])
ax[1].set_xlabel('Weighted Ratings from 1-10 in anime_meta')
ax[2].hist(rating_df['rating'])
ax[2].set_xlabel('Ratings from 1-10 in Rating Data')
plt.tight_layout()
plt.savefig('images/ratings_dist.png', dpi=300)
# Out:
# /Users/sherryduong/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/sherryduong/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
grouped = anime_full.groupby('type').mean()['avg_rating']
grouped2 = anime_full.groupby('type').mean()['weighted_rating']

fig, ax = plt.subplots(1,2, figsize=(16,3))
ax[0].bar(grouped.index, height=grouped.values)
ax[0].set_xlabel('Average Ratings from 1-10')
ax[1].bar(grouped2.index, height=grouped2.values)
ax[1].set_xlabel('Weighted Ratings from 1-10')
plt.tight_layout()
plt.savefig('images/ratings_per_type.png', dpi=300)

# %%
plt.style.use('ggplot')
grouped = anime_full.groupby('source').mean()['avg_rating']
grouped2 = anime_full.groupby('source').mean()['weighted_rating']

fig, ax = plt.subplots( figsize=(16,4))
ax.bar(grouped.index, height=grouped.values)
ax.set_xlabel('Average Ratings from 1-10')
# ax[1].bar(grouped2.index, height=grouped2.values)
# ax[1].set_xlabel('Weighted Ratings from 1-10')
plt.tight_layout()
plt.savefig('images/ratings_per_source.png', dpi=300)

# %%
grouped = anime_full.groupby('rating_type').mean()['avg_rating']
grouped2 = anime_full.groupby('rating_type').mean()['weighted_rating']

fig, ax = plt.subplots(1,2, figsize=(16,4))
ax[0].bar(grouped.index, height=grouped.values)
ax[0].set_xlabel('Average Ratings from 1-10')
ax[1].bar(grouped2.index, height=grouped2.values)
ax[1].set_xlabel('Weighted Ratings from 1-10')
plt.tight_layout()
plt.savefig('images/ratings_per_rating_type.png', dpi=300)

# %%
anime_full.groupby('rating_type').count()['anime_id']
# Out:
# rating_type
# G          3449
# PG         1148
# PG-13      4463
# R           896
# R+          841
# RX         1142
# Unknown     355
# Name: anime_id, dtype: int64

# %%
def explode_text(anime_full):
    exp_anime = anime_full.copy()
    #Fill all na's
    exp_anime['studio'] = exp_anime['studio'].fillna('Unknown')
    exp_anime['producer'] = exp_anime['producer'].fillna('Unknown')
    #explode all columns
    exp_anime = exp_anime.explode('genre')
    exp_anime['genre'] = exp_anime['genre'].transform(lambda x: x[1:] if x[0]==" " else x)
    exp_anime['studio'] = exp_anime['studio'].transform(lambda x: x.split(','))
    exp_anime = exp_anime.explode('studio')
    exp_anime['producer'] = exp_anime['producer'].transform(lambda x: x.split(','))
    exp_anime = exp_anime.explode('producer')
    return exp_anime

# %%
exp_anime = explode_text(anime_full)
exp_anime
# Out:
#        anime_id                                               name episodes  \
# 0         32281                                     Kimi No Na Wa.        1
# 0         32281                                     Kimi No Na Wa.        1
# 0         32281                                     Kimi No Na Wa.        1
# 0         32281                                     Kimi No Na Wa.        1
# 0         32281                                     Kimi No Na Wa.        1
# ...         ...                                                ...      ...
# 12289      9316       Toushindai My Lover: Minami Tai Mecha-Minami        1
# 12290      5543                                        Under World        1
# 12291      5621                     Violence Gekiga David No Hoshi        4
# 12292      6133  Violence Gekiga Shin David No Hoshi: Inma Dens...        1
# 12293     26081                   Yasuji No Pornorama: Yacchimae!!        1
#
#        avg_rating  members          title_english  \
# 0            9.37   200630             Your Name.
# 0            9.37   200630             Your Name.
# 0            9.37   200630             Your Name.
# 0            9.37   200630             Your Name.
# 0            9.37   200630             Your Name.
# ...           ...      ...                    ...
# 12289        4.15      211                    NaN
# 12290        4.28      183                    NaN
# 12291        4.88      219  Beautiful Girl Hunter
# 12292        4.98      175                    NaN
# 12293        5.46      142                    NaN
#
#                                                image_url   type    source  \
# 0      <img src="https://cdn.myanimelist.net/images/a...  Movie  Original
# 0      <img src="https://cdn.myanimelist.net/images/a...  Movie  Original
# 0      <img src="https://cdn.myanimelist.net/images/a...  Movie  Original
# 0      <img src="https://cdn.myanimelist.net/images/a...  Movie  Original
# 0      <img src="https://cdn.myanimelist.net/images/a...  Movie  Original
# ...                                                  ...    ...       ...
# 12289  <img src="https://cdn.myanimelist.net/images/a...    OVA   Unknown
# 12290  <img src="https://cdn.myanimelist.net/images/a...    OVA   Unknown
# 12291  <img src="https://cdn.myanimelist.net/images/a...    OVA   Unknown
# 12292  <img src="https://cdn.myanimelist.net/images/a...    OVA   Unknown
# 12293  <img src="https://cdn.myanimelist.net/images/a...  Movie   Unknown
#
#                 status                                       aired  \
# 0      Finished Airing  {'from': '2016-08-26', 'to': '2016-08-26'}
# 0      Finished Airing  {'from': '2016-08-26', 'to': '2016-08-26'}
# 0      Finished Airing  {'from': '2016-08-26', 'to': '2016-08-26'}
# 0      Finished Airing  {'from': '2016-08-26', 'to': '2016-08-26'}
# 0      Finished Airing  {'from': '2016-08-26', 'to': '2016-08-26'}
# ...                ...                                         ...
# 12289  Finished Airing  {'from': '2001-10-26', 'to': '2001-10-26'}
# 12290  Finished Airing  {'from': '2000-11-18', 'to': '2000-11-18'}
# 12291  Finished Airing  {'from': '1989-12-05', 'to': '1990-06-05'}
# 12292  Finished Airing  {'from': '1991-03-08', 'to': '1991-03-08'}
# 12293  Finished Airing  {'from': '1971-09-24', 'to': '1971-09-24'}
#
#               duration rating_type  rank  popularity  favorites  \
# 0        1 hr. 46 min.       PG-13   2.0        33.0    34912.0
# 0        1 hr. 46 min.       PG-13   2.0        33.0    34912.0
# 0        1 hr. 46 min.       PG-13   2.0        33.0    34912.0
# 0        1 hr. 46 min.       PG-13   2.0        33.0    34912.0
# 0        1 hr. 46 min.       PG-13   2.0        33.0    34912.0
# ...                ...         ...   ...         ...        ...
# 12289          30 min.          RX   NaN     10297.0        0.0
# 12290     1 hr. 4 min.          RX   NaN     10456.0        0.0
# 12291  45 min. per ep.          RX   NaN     10164.0        2.0
# 12292          45 min.          RX   NaN     10510.0        0.0
# 12293    1 hr. 41 min.          RX   NaN     10534.0        3.0
#
#                         producer            studio  \
# 0                Kadokawa Shoten  CoMix Wave Films
# 0                           Toho  CoMix Wave Films
# 0            Sound Team Don Juan  CoMix Wave Films
# 0       Lawson HMV Entertainment  CoMix Wave Films
# 0                          Amuse  CoMix Wave Films
# ...                          ...               ...
# 12289                    Unknown           Unknown
# 12290                    Unknown           Unknown
# 12291                    Unknown           Unknown
# 12292                    Unknown           Unknown
# 12293                    Unknown           Unknown
#
#                                       genre  \
# 0      Supernatural, Drama, Romance, School
# 0      Supernatural, Drama, Romance, School
# 0      Supernatural, Drama, Romance, School
# 0      Supernatural, Drama, Romance, School
# 0      Supernatural, Drama, Romance, School
# ...                                     ...
# 12289                                Hentai
# 12290                                Hentai
# 12291                                Hentai
# 12292                                Hentai
# 12293                                Hentai
#
#                              opening_theme  \
# 0      ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 0      ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 0      ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 0      ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 0      ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# ...                                    ...
# 12289                                   []
# 12290                                   []
# 12291                                   []
# 12292                                   []
# 12293                                   []
#
#                                    ending_theme  num_ratings  weighted_rating
# 0      ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0         9.169377
# 0      ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0         9.169377
# 0      ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0         9.169377
# 0      ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0         9.169377
# 0      ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0         9.169377
# ...                                         ...          ...              ...
# 12289                                        []          2.0         6.441523
# 12290                                        []          2.0         6.447341
# 12291                                        []          1.0         6.450864
# 12292                                        []          1.0         6.456597
# 12293                                        []          NaN         6.464351
#
# [20663 rows x 23 columns]

# %%
exp_anime['studio'] = exp_anime['studio'].transform(lambda x: x[1:] if x[0]==' ' else x)
exp_anime['producer'] = exp_anime['producer'].transform(lambda x: x[1:] if x[0]==' ' else x)

# %%
exp_anime = anime_full.copy()
# exp_anime['genre'] = exp_anime['genre'].transform(lambda x: x.split(','))
exp_anime = exp_anime.explode('genre')
exp_anime['genre'] = exp_anime['genre'].transform(lambda x: x[1:] if x[0]==" " else x)
exp_anime
# Out:
#        anime_id                                               name episodes  \
# 0         32281                                     Kimi No Na Wa.        1
# 1          5114                   Fullmetal Alchemist: Brotherhood       64
# 2         28977                                           Gintama°       51
# 3          9253                                        Steins;Gate       24
# 4          9969                                      Gintama&#039;       51
# ...         ...                                                ...      ...
# 12289      9316       Toushindai My Lover: Minami Tai Mecha-Minami        1
# 12290      5543                                        Under World        1
# 12291      5621                     Violence Gekiga David No Hoshi        4
# 12292      6133  Violence Gekiga Shin David No Hoshi: Inma Dens...        1
# 12293     26081                   Yasuji No Pornorama: Yacchimae!!        1
#
#        avg_rating  members                     title_english  \
# 0            9.37   200630                        Your Name.
# 1            9.26   793665  Fullmetal Alchemist: Brotherhood
# 2            9.25   114262                  Gintama Season 4
# 3            9.17   673572                       Steins;Gate
# 4            9.16   151266                  Gintama Season 2
# ...           ...      ...                               ...
# 12289        4.15      211                               NaN
# 12290        4.28      183                               NaN
# 12291        4.88      219             Beautiful Girl Hunter
# 12292        4.98      175                               NaN
# 12293        5.46      142                               NaN
#
#                                                image_url   type        source  \
# 0      <img src="https://cdn.myanimelist.net/images/a...  Movie      Original
# 1      <img src="https://cdn.myanimelist.net/images/a...     TV         Manga
# 2      <img src="https://cdn.myanimelist.net/images/a...     TV         Manga
# 3      <img src="https://cdn.myanimelist.net/images/a...     TV  Visual novel
# 4      <img src="https://cdn.myanimelist.net/images/a...     TV         Manga
# ...                                                  ...    ...           ...
# 12289  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12290  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12291  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12292  <img src="https://cdn.myanimelist.net/images/a...    OVA       Unknown
# 12293  <img src="https://cdn.myanimelist.net/images/a...  Movie       Unknown
#
#                 status                                       aired  \
# 0      Finished Airing  {'from': '2016-08-26', 'to': '2016-08-26'}
# 1      Finished Airing  {'from': '2009-04-05', 'to': '2010-07-04'}
# 2      Finished Airing  {'from': '2015-04-08', 'to': '2016-03-30'}
# 3      Finished Airing  {'from': '2011-04-06', 'to': '2011-09-14'}
# 4      Finished Airing  {'from': '2011-04-04', 'to': '2012-03-26'}
# ...                ...                                         ...
# 12289  Finished Airing  {'from': '2001-10-26', 'to': '2001-10-26'}
# 12290  Finished Airing  {'from': '2000-11-18', 'to': '2000-11-18'}
# 12291  Finished Airing  {'from': '1989-12-05', 'to': '1990-06-05'}
# 12292  Finished Airing  {'from': '1991-03-08', 'to': '1991-03-08'}
# 12293  Finished Airing  {'from': '1971-09-24', 'to': '1971-09-24'}
#
#               duration rating_type  rank  popularity  favorites  \
# 0        1 hr. 46 min.       PG-13   2.0        33.0    34912.0
# 1      24 min. per ep.           R   1.0         4.0   106895.0
# 2      24 min. per ep.           R   3.0       383.0     5668.0
# 3      24 min. per ep.       PG-13   5.0         8.0    92423.0
# 4      24 min. per ep.       PG-13   7.0       342.0     4549.0
# ...                ...         ...   ...         ...        ...
# 12289          30 min.          RX   NaN     10297.0        0.0
# 12290     1 hr. 4 min.          RX   NaN     10456.0        0.0
# 12291  45 min. per ep.          RX   NaN     10164.0        2.0
# 12292          45 min.          RX   NaN     10510.0        0.0
# 12293    1 hr. 41 min.          RX   NaN     10534.0        3.0
#
#                                                 producer  \
# 0      Kadokawa Shoten, Toho, Sound Team Don Juan, La...
# 1      Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 2                              TV Tokyo, Aniplex, Dentsu
# 3      Frontier Works, Media Factory, Movic, AT-X, Ka...
# 4      TV Tokyo, Aniplex, Dentsu, Trinity Sound, Mira...
# ...                                                  ...
# 12289                                            Unknown
# 12290                                            Unknown
# 12291                                            Unknown
# 12292                                            Unknown
# 12293                                            Unknown
#
#                       studio  \
# 0           CoMix Wave Films
# 1                      Bones
# 2      Bandai Namco Pictures
# 3                  White Fox
# 4                    Sunrise
# ...                      ...
# 12289                Unknown
# 12290                Unknown
# 12291                Unknown
# 12292                Unknown
# 12293                Unknown
#
#                                                    genre  \
# 0                   Supernatural, Drama, Romance, School
# 1      Action, Military, Adventure, Comedy, Drama, Ma...
# 2      Action, Comedy, Historical, Parody, Samurai, S...
# 3                                       Thriller, Sci-Fi
# 4      Action, Sci-Fi, Comedy, Historical, Parody, Sa...
# ...                                                  ...
# 12289                                             Hentai
# 12290                                             Hentai
# 12291                                             Hentai
# 12292                                             Hentai
# 12293                                             Hentai
#
#                                            opening_theme  \
# 0                    ['"Yume Tourou (夢灯籠)" by RADWIMPS']
# 1      ['#1: "again" by YUI (eps 1-14)', '#2: "Hologr...
# 2      ['#1: "DAY×DAY" by BLUE ENCOUNT (eps 1-12)', '...
# 3               ['"Hacking to the Gate" by Kanako Itou']
# 4      ['#1: "Tougenkyou Alien (桃源郷エイリアン)" by serial ...
# ...                                                  ...
# 12289                                                 []
# 12290                                                 []
# 12291                                                 []
# 12292                                                 []
# 12293                                                 []
#
#                                             ending_theme  num_ratings  \
# 0               ['"Nandemonaiya (なんでもないや)" by RADWIMPS']       1961.0
# 1      ['#1: "Uso (嘘)" by SID (eps 1-14)', '#2: "LET ...      21494.0
# 2      ['#1: "DESTINY" by Negoto (eps 1-12)', '#2: "S...       1188.0
# 3      ['#1: "Toki Tsukasadoru Juuni no Meiyaku (刻司ル十...      17151.0
# 4      ['#1: "Samurai Heart (Some Like It Hot!!)" by ...       3115.0
# ...                                                  ...          ...
# 12289                                                 []          2.0
# 12290                                                 []          2.0
# 12291                                                 []          1.0
# 12292                                                 []          1.0
# 12293                                                 []          NaN
#
#        weighted_rating
# 0             9.169377
# 1             9.208548
# 2             8.929129
# 3             9.111525
# 4             8.918657
# ...                ...
# 12289         6.441523
# 12290         6.447341
# 12291         6.450864
# 12292         6.456597
# 12293         6.464351
#
# [12294 rows x 23 columns]

# %%
viz = exp_anime.groupby('genre').mean()['avg_rating'].sort_values(ascending=False)
viz2 = exp_anime.groupby('genre').mean()['weighted_rating'].sort_values(ascending=False)

fig, ax = plt.subplots( figsize=(16,4))
ax.bar(x=viz.index, height=viz.values)
ax.set_xticklabels(labels=viz.index, rotation=90)
ax.set_title('Average Ratings Per Genre')
# ax[1].bar(x=viz2.index, height=viz2.values)
# ax[1].set_xticklabels(labels=viz2.index, rotation=90)
# ax[1].set_title('Weighted Average Ratings Per Genre')

plt.tight_layout()
# plt.savefig('images/ratings_per_genre.png', dpi=300)
plt.show()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:12: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   if sys.path[0] == '':

# %%
# exp_anime_studio = exp_anime.copy()
# exp_anime_studio['studio'] = exp_anime_studio['studio'].fillna('Unknown')
# exp_anime_studio['studio'] = exp_anime_studio['studio'].transform(lambda x: x.split(','))
# exp_anime_studio = exp_anime_studio.explode('studio')
# exp_anime_studio

# %%
viz = exp_anime.groupby('studio').mean()[['avg_rating','weighted_rating']].sort_values(by='weighted_rating',ascending=False)[:20]

plt.figure(figsize=(8,5))
sns.barplot(x='weighted_rating', y=viz.index, data=viz)
plt.xlabel('Top 20 Anime Studios by Weighted Rating')
plt.tight_layout()
plt.savefig('images/ratings_per_studio.png', dpi=300)

# %%
viz.index[:20]
# Out:
# Index(['Studio Chizu', 'Marvy Jack', 'Bandai Namco Pictures', 'White Fox',
#        'Purple Cow Studio Japan', 'Shuka', 'Egg Firm', 'Square Enix',
#        'Wit Studio', 'Lay-duce', 'Studio Ghibli', 'Graphinica',
#        'David Production', 'Bridge', 'Animation Do', 'P.A. Works',
#        'Kyoto Animation', 'Manglobe', 'Artland', 'Hoods Drifters Studio'],
#       dtype='object', name='studio')

# %%
exp_anime_producer = exp_anime.copy()
exp_anime_producer['producer'] = exp_anime_producer['producer'].fillna('Unknown')
exp_anime_producer['producer'] = exp_anime_producer['producer'].transform(lambda x: x.split(','))
exp_anime_producer = exp_anime_producer.explode('producer')

# %%
viz2 = exp_anime.groupby('producer').mean()[['avg_rating','weighted_rating']].sort_values(by='weighted_rating',ascending=False).head(20)
plt.figure(figsize=(8,5))
sns.barplot(x='weighted_rating', y=viz2.index, data=viz2)
plt.xlabel('Top 20 Anime Producers by Weighted Rating')
plt.tight_layout()
plt.savefig('images/ratings_per_producers.png', dpi=300)

# %%
viz2.index[:20]
# Out:
# Index(['Studio Moriken', 'Quaras', 'Seikaisha', 'Mad Box',
#        'Forecast Communications', 'StudioRF Inc.', 'CIC', 'TAP',
#        'Miracle Robo', 'Madoka Partners', 'Animation Do', 'Studio Wombat',
#        'GYAO!', 'Shingeki no Kyojin Team', 'C &amp; I entertainment',
#        'Top-Insight International Co.', 'LTD.',
#        'East Japan Marketing &amp; Communications', 'Audio Highs',
#        'Banpresto'],
#       dtype='object', name='producer')

# %%
anime_full['duration']
# Out:
# 0          1 hr. 46 min.
# 1        24 min. per ep.
# 2        24 min. per ep.
# 3        24 min. per ep.
# 4        24 min. per ep.
#               ...
# 12289            30 min.
# 12290       1 hr. 4 min.
# 12291    45 min. per ep.
# 12292            45 min.
# 12293      1 hr. 41 min.
# Name: duration, Length: 12294, dtype: object

# %% [markdown]
# ## Combine user_meta & rating_df

# %%
users_meta
# Out:
#                 username  user_id  user_watching  user_completed  user_onhold  \
# 0               karthiga  2255153              3              49            1
# 1       RedvelvetDaisuki  1897606             61             396           39
# 2              Damonashu    37326             45             195           27
# 3                  bskai   228342             25             414            2
# 4              shuzzable  2347781             36              72           16
# ...                  ...      ...            ...             ...          ...
# 302670      ScruffyPuffy  3119025              0              27            0
# 302671          Torasori  3975907             22             239            0
# 302672              onpc  1268417              5             169            2
# 302673            HMicca  1289601             11              73            2
# 302674        mini_kaila   236339              2              10            5
#
#         user_dropped  user_plantowatch  user_days_spent_watching  gender  \
# 0                  0                 0                     55.31  Female
# 1                  0               206                    118.07  Female
# 2                 25                59                     83.70    Male
# 3                  5                11                    167.16    Male
# 4                  2                25                     35.48     NaN
# ...              ...               ...                       ...     ...
# 302670             0                 0                      7.92     NaN
# 302671             4               176                     86.88    Male
# 302672             5                24                     38.36    Male
# 302673             2                16                    119.97  Female
# 302674             3                 5                      4.17  Female
#
#                    location  birth_date  access_rank   join_date  \
# 0           Chennai, India   1990-04-29          NaN  2013-03-03
# 1                    Manila  1995-01-01          NaN  2012-12-13
# 2          Detroit,Michigan  1991-08-01          NaN  2008-02-13
# 3           Nayarit, Mexico  1990-12-14          NaN  2009-08-31
# 4                       NaN         NaN          NaN  2013-03-25
# ...                     ...         ...          ...         ...
# 302670                  NaN         NaN          NaN  2013-09-06
# 302671         Latvia, Riga  1998-11-18          NaN  2014-07-30
# 302672                  NaN         NaN          NaN  2012-04-23
# 302673  Birmingham, England  1995-08-12          NaN  2012-05-05
# 302674                  NaN         NaN          NaN  2009-09-19
#
#                 last_online  stats_mean_score  stats_rewatched  stats_episodes
# 0       2014-02-04 01:32:00              7.43              0.0          3391.0
# 1       1900-05-13 02:47:00              6.78             80.0          7094.0
# 2       1900-03-24 12:48:00              6.15              6.0          4936.0
# 3       2014-05-12 16:35:00              8.27              1.0         10081.0
# 4       2015-09-09 21:54:00              9.06              7.0          2154.0
# ...                     ...               ...              ...             ...
# 302670  2014-10-10 09:04:00              0.00              0.0           477.0
# 302671  2018-05-24 21:34:46              8.98             47.0          5313.0
# 302672  2016-12-28 14:35:00              7.72              0.0          2280.0
# 302673  2012-11-15 08:10:00              8.89             11.0          7049.0
# 302674  2011-08-19 01:15:00              7.82              0.0           245.0
#
# [302675 rows x 17 columns]

# %%
rating_df
# Out:
#          user_id  anime_id  rating
# 47             1      8074      10
# 81             1     11617      10
# 83             1     11757      10
# 101            1     15451      10
# 153            2     11771      10
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [6337241 rows x 3 columns]

# %%
ratings_user = rating_df.merge(right=users_meta, how='left', on='user_id')
ratings_user
# Out:
#          user_id  anime_id  rating username  user_watching  user_completed  \
# 0              1      8074      10    Xinil            4.0           230.0
# 1              1     11617      10    Xinil            4.0           230.0
# 2              1     11757      10    Xinil            4.0           230.0
# 3              1     15451      10    Xinil            4.0           230.0
# 4              2     11771      10      NaN            NaN             NaN
# ...          ...       ...     ...      ...            ...             ...
# 6337236    73515     16512       7      NaN            NaN             NaN
# 6337237    73515     17187       9      NaN            NaN             NaN
# 6337238    73515     22145      10      NaN            NaN             NaN
# 6337239    73516       790       9      NaN            NaN             NaN
# 6337240    73516      8074       9      NaN            NaN             NaN
#
#          user_onhold  user_dropped  user_plantowatch  \
# 0                8.0          89.0              60.0
# 1                8.0          89.0              60.0
# 2                8.0          89.0              60.0
# 3                8.0          89.0              60.0
# 4                NaN           NaN               NaN
# ...              ...           ...               ...
# 6337236          NaN           NaN               NaN
# 6337237          NaN           NaN               NaN
# 6337238          NaN           NaN               NaN
# 6337239          NaN           NaN               NaN
# 6337240          NaN           NaN               NaN
#
#          user_days_spent_watching gender    location  birth_date  access_rank  \
# 0                          133.32   Male  California  1985-03-04          NaN
# 1                          133.32   Male  California  1985-03-04          NaN
# 2                          133.32   Male  California  1985-03-04          NaN
# 3                          133.32   Male  California  1985-03-04          NaN
# 4                             NaN    NaN         NaN         NaN          NaN
# ...                           ...    ...         ...         ...          ...
# 6337236                       NaN    NaN         NaN         NaN          NaN
# 6337237                       NaN    NaN         NaN         NaN          NaN
# 6337238                       NaN    NaN         NaN         NaN          NaN
# 6337239                       NaN    NaN         NaN         NaN          NaN
# 6337240                       NaN    NaN         NaN         NaN          NaN
#
#           join_date          last_online  stats_mean_score  stats_rewatched  \
# 0        2004-11-05  2018-05-14 18:02:55              7.37             58.0
# 1        2004-11-05  2018-05-14 18:02:55              7.37             58.0
# 2        2004-11-05  2018-05-14 18:02:55              7.37             58.0
# 3        2004-11-05  2018-05-14 18:02:55              7.37             58.0
# 4               NaN                  NaN               NaN              NaN
# ...             ...                  ...               ...              ...
# 6337236         NaN                  NaN               NaN              NaN
# 6337237         NaN                  NaN               NaN              NaN
# 6337238         NaN                  NaN               NaN              NaN
# 6337239         NaN                  NaN               NaN              NaN
# 6337240         NaN                  NaN               NaN              NaN
#
#          stats_episodes
# 0                7920.0
# 1                7920.0
# 2                7920.0
# 3                7920.0
# 4                   NaN
# ...                 ...
# 6337236             NaN
# 6337237             NaN
# 6337238             NaN
# 6337239             NaN
# 6337240             NaN
#
# [6337241 rows x 19 columns]

# %%
ratings_user[ratings_user['username'].isnull()]
#4M out of 6M ratings will have no user profiles
# Out:
#          user_id  anime_id  rating username  user_watching  user_completed  \
# 4              2     11771      10      NaN            NaN             NaN
# 97             5         6       8      NaN            NaN             NaN
# 98             5        15       6      NaN            NaN             NaN
# 99             5        17       6      NaN            NaN             NaN
# 100            5        18       6      NaN            NaN             NaN
# ...          ...       ...     ...      ...            ...             ...
# 6337236    73515     16512       7      NaN            NaN             NaN
# 6337237    73515     17187       9      NaN            NaN             NaN
# 6337238    73515     22145      10      NaN            NaN             NaN
# 6337239    73516       790       9      NaN            NaN             NaN
# 6337240    73516      8074       9      NaN            NaN             NaN
#
#          user_onhold  user_dropped  user_plantowatch  \
# 4                NaN           NaN               NaN
# 97               NaN           NaN               NaN
# 98               NaN           NaN               NaN
# 99               NaN           NaN               NaN
# 100              NaN           NaN               NaN
# ...              ...           ...               ...
# 6337236          NaN           NaN               NaN
# 6337237          NaN           NaN               NaN
# 6337238          NaN           NaN               NaN
# 6337239          NaN           NaN               NaN
# 6337240          NaN           NaN               NaN
#
#          user_days_spent_watching gender location birth_date  access_rank  \
# 4                             NaN    NaN      NaN        NaN          NaN
# 97                            NaN    NaN      NaN        NaN          NaN
# 98                            NaN    NaN      NaN        NaN          NaN
# 99                            NaN    NaN      NaN        NaN          NaN
# 100                           NaN    NaN      NaN        NaN          NaN
# ...                           ...    ...      ...        ...          ...
# 6337236                       NaN    NaN      NaN        NaN          NaN
# 6337237                       NaN    NaN      NaN        NaN          NaN
# 6337238                       NaN    NaN      NaN        NaN          NaN
# 6337239                       NaN    NaN      NaN        NaN          NaN
# 6337240                       NaN    NaN      NaN        NaN          NaN
#
#         join_date last_online  stats_mean_score  stats_rewatched  \
# 4             NaN         NaN               NaN              NaN
# 97            NaN         NaN               NaN              NaN
# 98            NaN         NaN               NaN              NaN
# 99            NaN         NaN               NaN              NaN
# 100           NaN         NaN               NaN              NaN
# ...           ...         ...               ...              ...
# 6337236       NaN         NaN               NaN              NaN
# 6337237       NaN         NaN               NaN              NaN
# 6337238       NaN         NaN               NaN              NaN
# 6337239       NaN         NaN               NaN              NaN
# 6337240       NaN         NaN               NaN              NaN
#
#          stats_episodes
# 4                   NaN
# 97                  NaN
# 98                  NaN
# 99                  NaN
# 100                 NaN
# ...                 ...
# 6337236             NaN
# 6337237             NaN
# 6337238             NaN
# 6337239             NaN
# 6337240             NaN
#
# [4039329 rows x 19 columns]

# %%
ratings_user[~ratings_user['username'].isnull()]['anime_id'].nunique()
# Out:
# 8939

# %%
rating_df['rating'].hist()
plt.title('Average Ratings from Rating Data')
plt.savefig('images/avg_user_rating.png', dpi=300)

# %%
ratings_user[ratings_user.isnull()]
# Out:
#          user_id  anime_id  rating username  user_watching  user_completed  \
# 0            NaN       NaN     NaN      NaN            NaN             NaN
# 1            NaN       NaN     NaN      NaN            NaN             NaN
# 2            NaN       NaN     NaN      NaN            NaN             NaN
# 3            NaN       NaN     NaN      NaN            NaN             NaN
# 4            NaN       NaN     NaN      NaN            NaN             NaN
# ...          ...       ...     ...      ...            ...             ...
# 6337236      NaN       NaN     NaN      NaN            NaN             NaN
# 6337237      NaN       NaN     NaN      NaN            NaN             NaN
# 6337238      NaN       NaN     NaN      NaN            NaN             NaN
# 6337239      NaN       NaN     NaN      NaN            NaN             NaN
# 6337240      NaN       NaN     NaN      NaN            NaN             NaN
#
#          user_onhold  user_dropped  user_plantowatch  \
# 0                NaN           NaN               NaN
# 1                NaN           NaN               NaN
# 2                NaN           NaN               NaN
# 3                NaN           NaN               NaN
# 4                NaN           NaN               NaN
# ...              ...           ...               ...
# 6337236          NaN           NaN               NaN
# 6337237          NaN           NaN               NaN
# 6337238          NaN           NaN               NaN
# 6337239          NaN           NaN               NaN
# 6337240          NaN           NaN               NaN
#
#          user_days_spent_watching gender location birth_date  access_rank  \
# 0                             NaN    NaN      NaN        NaN          NaN
# 1                             NaN    NaN      NaN        NaN          NaN
# 2                             NaN    NaN      NaN        NaN          NaN
# 3                             NaN    NaN      NaN        NaN          NaN
# 4                             NaN    NaN      NaN        NaN          NaN
# ...                           ...    ...      ...        ...          ...
# 6337236                       NaN    NaN      NaN        NaN          NaN
# 6337237                       NaN    NaN      NaN        NaN          NaN
# 6337238                       NaN    NaN      NaN        NaN          NaN
# 6337239                       NaN    NaN      NaN        NaN          NaN
# 6337240                       NaN    NaN      NaN        NaN          NaN
#
#         join_date last_online  stats_mean_score  stats_rewatched  \
# 0             NaN         NaN               NaN              NaN
# 1             NaN         NaN               NaN              NaN
# 2             NaN         NaN               NaN              NaN
# 3             NaN         NaN               NaN              NaN
# 4             NaN         NaN               NaN              NaN
# ...           ...         ...               ...              ...
# 6337236       NaN         NaN               NaN              NaN
# 6337237       NaN         NaN               NaN              NaN
# 6337238       NaN         NaN               NaN              NaN
# 6337239       NaN         NaN               NaN              NaN
# 6337240       NaN         NaN               NaN              NaN
#
#          stats_episodes
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 6337236             NaN
# 6337237             NaN
# 6337238             NaN
# 6337239             NaN
# 6337240             NaN
#
# [6337241 rows x 19 columns]

# %%
rating_df['user_id'].nunique()
# Out:
# 69600

# %%
rating_df['anime_id'].nunique()
# Out:
# 9927

# %%
grouped = rating_df.groupby('anime_id').count().sort_values('rating',ascending=False)

# %%
grouped[grouped['rating']<5]
# Out:
#           user_id  rating
# anime_id
# 9645            4       4
# 27653           4       4
# 10751           4       4
# 24743           4       4
# 4709            4       4
# ...           ...     ...
# 30403           1       1
# 30404           1       1
# 30405           1       1
# 30407           1       1
# 11695           1       1
#
# [1897 rows x 2 columns]

# %% [markdown]
# ## Clustering the studio & producers

# %%
from sklearn.feature_extraction.text import CountVectorizer
ContBased_3 = anime_full[['anime_id','type','source','rating_type','weighted_rating','studio','producer']]
vect = CountVectorizer()
count_vect = vect.fit_transform(anime_full['genre'])
features = vect.get_feature_names()
genre_matrix = count_vect.toarray()
genre_df = pd.DataFrame(genre_matrix, columns =features, index=anime_full['anime_id'])

# %%
ContBased_3['producer'] = ContBased_3['producer'].transform(lambda x: x.split(','))
ContBased_3['studio'] = ContBased_3['studio'].transform(lambda x: x.split(','))
# Out:
# /Users/sherryduong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/sherryduong/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
new_df = ContBased_3.explode('studio')
new_df = new_df.explode('producer')
new_df['studio'] = new_df['studio'].transform(lambda x: x[1:] if x[0]==" " else x)
new_df['producer'] = new_df['producer'].transform(lambda x: x[1:] if x[0]==" " else x)
studios = new_df['studio'].unique()
producers = new_df['producer'].unique()

# %%
studio_matrix = pd.DataFrame()
producer_matrix = pd.DataFrame()
for studio in studios:
    studio_matrix[studio] = ContBased_3['studio'].transform(lambda x: 1 if studio in x else 0)
for producer in producers:
    producer_matrix[producer] = ContBased_3['producer'].transform(lambda x: 1 if producer in x else 0)
import os
os.system("say 'Complete'")
# Out:
# 0

# %%
from sklearn.decomposition import NMF
nmf = NMF(n_components=5)
W2 = nmf.fit_transform(studio_matrix)
H2 = nmf.components_
df = pd.DataFrame(studio_matrix, columns=studio_matrix.columns)
H_df2 = pd.DataFrame(H2)
topics = {}
for row in H_df2.index:
    top_words = H_df2.iloc[row,:].sort_values(ascending=False).head(10).index
    topics[row] = df.columns[top_words]
topics
# Out:
# {0: Index(['Unknown', 'Sugar Boy', 'Studio World', 'Sparkly Key Animation Studio',
#         'Enoki Films', 'Dai Nippon Printing', 'Karaku', 'Fanworks',
#         'Digital Frontier', 'Steve N&#039; Steven'],
#        dtype='object'),
#  1: Index(['Toei Animation', 'Xebec', 'Gonzo', 'Bones', 'Shaft',
#         'G.CMay Animation &amp; Film', 'Dai Nippon Printing', 'Karaku',
#         'Fanworks', 'Digital Frontier'],
#        dtype='object'),
#  2: Index(['Sunrise', 'Nippon Animation', 'OLM', 'Tatsunoko Production', 'AIC',
#         'Shaft', 'Kyoto Animation', 'Satelight', 'Studio World',
#         'Studio Junio'],
#        dtype='object'),
#  3: Index(['Madhouse', 'Production I.G', 'Studio Pierrot', 'A-1 Pictures',
#         'Shin-Ei Animation', 'Xebec', 'Gonzo', 'Bones', 'Kyoto Animation',
#         'Gainax'],
#        dtype='object'),
#  4: Index(['J.C.Staff', 'Production I.G', 'Studio Pierrot', 'Studio Deen',
#         'A-1 Pictures', 'Shin-Ei Animation', 'Xebec', 'Gonzo',
#         'Kyoto Animation', 'Brain&#039;s Base'],
#        dtype='object')}

# %%
nmf = NMF(n_components=5)
W2 = nmf.fit_transform(producer_matrix)
H2 = nmf.components_
df = pd.DataFrame(producer_matrix, columns=producer_matrix.columns)
H_df2 = pd.DataFrame(H2)
topics = {}
for row in H_df2.index:
    top_words = H_df2.iloc[row,:].sort_values(ascending=False).head(10).index
    topics[row] = df.columns[top_words]
topics
# Out:
# {0: Index(['Unknown', 'Allure', 'Shin-Ei Animation', 'CREi', 'Kinoshita Koumuten',
#         'Ichijinsha', 'Studio Zain', 'Yumeta Company', 'Anime Consortium Japan',
#         'Japan Home Video'],
#        dtype='object'),
#  1: Index(['TV Tokyo', 'TV Asahi', 'VAP', 'Starchild Records', 'Sotsu',
#         'Pony Canyon', 'Kadokawa Shoten', 'Genco',
#         'Geneon Universal Entertainment', 'Tokyo Movie Shinsha'],
#        dtype='object'),
#  2: Index(['Bandai Visual', 'Fuji TV', 'TV Asahi', 'TBS', 'Dentsu', 'Gakken',
#         'AIC', 'Frontier Works', 'CoMix Wave Films', 'Mushi Production'],
#        dtype='object'),
#  3: Index(['Aniplex', 'Lantis', 'Fuji TV', 'Milky Animation Label',
#         'Tokyo Movie Shinsha', 'DAX Production', 'Studio Zain', 'Ichijinsha',
#         'Kinoshita Koumuten', 'Yumeta Company'],
#        dtype='object'),
#  4: Index(['NHK', 'TV Asahi', 'VAP', 'Starchild Records', 'Tokyo Movie Shinsha',
#         'Sotsu', 'Pony Canyon', 'Genco', 'Milky Animation Label', 'AIC'],
#        dtype='object')}

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(5)
km= kmeans.fit(producer_matrix)

# %%
top_centroids = km.cluster_centers_.argsort()[:,-1:-6:-1]
print("Clusters of Producers:")
for num, centroid in enumerate(top_centroids):
    print(f"{num}, {', '.join(producer_matrix.columns[i] for i in centroid)}")
# Out:
# Clusters of Producers:
# 0, Bandai Visual, Pink Pineapple, Lantis, Sanrio, Fuji TV
# 1, Unknown, Bandai Visual, Aniplex, NHK, TV Tokyo
# 2, TV Tokyo, Tokyo Movie Shinsha, Sanrio, Sotsu, Milky Animation Label
# 3, NHK, Sanrio, Tokyo Movie Shinsha, Fuji TV, Milky Animation Label
# 4, Aniplex, Tokyo Movie Shinsha, Sanrio, Fuji TV, Milky Animation Label

# %%
km2= kmeans.fit(studio_matrix)
top_centroids = km2.cluster_centers_.argsort()[:,-1:-6:-1]
print("Clusters of Studios:")
for num, centroid in enumerate(top_centroids):
    print(f"{num}, {', '.join(studio_matrix.columns[i] for i in centroid)}")
# Out:
# Clusters of Studios:
# 0, Sunrise, Madhouse, Production I.G, Studio Pierrot, TMS Entertainment
# 1, Unknown, Sunrise, Madhouse, J.C.Staff, Studio Pierrot
# 2, Studio Deen, Toei Animation, Sunrise, OLM, Xebec
# 3, J.C.Staff, Toei Animation, Sunrise, OLM, Xebec
# 4, Toei Animation, Unknown, Nippon Animation, OLM, Tatsunoko Production

# %%
studio_dict = {'Studio 1': ['Aniplex', 'Studio Jack', 'East Japan Marketing &amp; Communications', 'Kadokawa Pictures Japan', 'Kitty Films'],
              'Studio 2': ['Amuse', 'NHK', 'TBS', 'Hakuhodo DY Media Partners', 'Sony Music Entertainment'],
              'Studio 3': ['NHK', 'Amuse', 'Aniplex', 'Studio Jack', 'Kadokawa Pictures Japan'],
              'Studio 4': ['TBS', 'NHK', 'Hakuhodo DY Media Partners', 'Sony Music Entertainment', 'VAP'],
              'Studio 5': ['Media Factory', 'TBS', 'Amuse', 'Sony Music Entertainment', 'Kodansha']}
producer_dict = {'Producer 1': ['Sunrise', 'J.C.Staff', 'Studio Pierrot', 'TMS Entertainment', 'Studio Deen'],
              'Producer 2': ['Unknown', 'Sunrise', 'Madhouse', 'J.C.Staff', 'Studio Pierrot'],
              'Producer 3': ['Toei Animation', 'Unknown', 'Nippon Animation', 'OLM', 'Tatsunoko Production'],
              'Producer 4': ['Madhouse', 'Toei Animation', 'Sunrise', 'OLM', 'Xebec'],
              'Producer 5': ['Production I.G', 'Toei Animation', 'Sunrise', 'OLM,' 'Xebec']}
